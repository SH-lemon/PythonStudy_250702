# %% [markdown]
# ```
# 인터파크 티켓에서 공연 카테고리를 클릭해 공연명과 일정 정보를 수집하세요.
# 신세계몰에서 ‘식품’ 카테고리의 오늘의 특가 상품명을 수집하세요.
# 페이스북 로그인 후 특정 페이지의 최근 게시글 제목을 수집하세요.
# 카카오맵에서 '맛집' 검색 후 스크롤하여 장소명과 별점을 수집하세요.
# ```

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://tickets.interpark.com/contents/genre/musical"

driver.get(url)
time.sleep(2)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

table = []

titles = driver.find_elements(By.XPATH, "//li[@class='TicketItem_goodsName__Ju76j']")
dates = driver.find_elements(By.XPATH, "//li[@class='TicketItem_playDate__5ePr2']")

for t, d in zip(titles, dates) :
    table.append({"제목" : t.text.strip(), "일정" : d.text.strip()})
MusicalTable = pd.DataFrame(table)

driver.quit()
MusicalTable
# Out:
#                        제목                       일정
# 0                세비야의 이발사  2025.03.14 - 2026.03.04
# 1                최현우 19+I  2025.03.29 - 2025.09.21
# 2   마하랑 떠나요 - 수도SONG 세계여행  2025.02.15 - 2025.09.30
# 3                 와일드 와일드  2025.06.13 - 2025.12.31
# 4            연남동 빙굴빙굴 빨래방                 OPEN RUN
# 5                 점프 JUMP                 OPEN RUN
# 6                     썸데이                 OPEN RUN
# 7                    페인터즈                 OPEN RUN
# 8                     써니텐                 OPEN RUN
# 9                    천로역정                 OPEN RUN
# 10             TOUCH FIVE                 OPEN RUN
# 11                  바리케이드  2025.08.13 - 2025.08.17
# 12               해피 오! 해피  2025.08.20 - 2025.11.09
# 13                     심청  2025.09.03 - 2025.09.06
# 14                  Dear.  2025.08.07 - 2025.10.31

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://shinsegaemall.ssg.com/page/pc/happybuy.ssg?trackingId=6000083344"

driver.get(url)
time.sleep(2)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

food = driver.find_elements(By.CSS_SELECTOR, "p.chakra-text.css-19bfb2a")

for f in food :
    print(f.text.strip())

driver.quit()
# Out:
# STACCATO패밀리 세일 최저가 도전
# 득템의 찬스 + 추가쿠폰 혜택
# 지센썸머 클리어런스
# ~90%, 무료배송
# 한국금다이아몬드랩다이아몬드 1캐럿 외
# ~60% 할인 사은품&쿠폰최대지원
# 엘렌쥬얼리14K 물고기 반지
# ~20%+10% 행운의 주얼리
# 온앤온#기은세 #정채연 착용
# 최대50% + 다운로드 쿠폰
# 마시모두띠FW 25 뉴 컬렉션 런칭
# 지금 사랑받는 인기 상품
# 브룩스브라더스25 S/S 시즌오프
# 최대 50% + 추가할인
# 시디즈링고 1세대 단독특가부터
# 베스트 상품까지!
# LGLG 휘센 오브제컬렉션 쿨
# 6%할인+카드청구할인
# 버버리명품 클리어런스 연합전
# 지금이기회 최대할인 ~80%
# 배럴여름 바캉스 준비
# 쿠폰할인 혜택
# 위시드여름 시즌오프 40%
# 기간 한정 추가 쿠폰
# 에스카다명품에서 패션까지 선글라스찬스
# ~88% 할인, 사은품 지급
# 주방/청소용품
# 최대 27% 할인
# 블랙야크남여 냉감 기능성 반팔티
# 추가 할인 혜택
# 모두투어 해외여행괌 두짓비치 클럽룸 특가
# 클럽라운지 혜택
# 크록스바야밴드 클로그 균일가전
# + 18%즉시할인 혜택
# 발뮤다발뮤다 그린팬S
# 27% 할인
# 아르마니 뷰티프리마 글로우 쿠션 사전예약
# 쿠션 미니어처+미니향수 증정
# 클라이드앤2024년 S/S
# 여름특가 및 신상세일
# 더로우신상&시즌오프
# 여성잡화 연합전 TOP 50
# CJ제일제당닭가슴살 깜짝특가
# 57%할인행사
# 라라르떼나의 복숭아 취향 고르기!
# S머니 10% 추가할인
# 뮤디스MF-300L PLUS피아노
# 브랜드관쿠폰+리뷰사은증정
# 노스페이스1992 눕시 자켓
# 추가 할인 혜택
# 압소바국민 육아템 브라운체온계
# SSG 특가찬스
# 케노샤홈베스트 침구 한눈에쓱
# 추가할인 적립까지
# 르네휘테르포티샤 마스크 트리오
# 포티샤샴푸 정품 증정
# 시몬스판매1위 슈퍼싱글 매트리스
# SSG 비밀특가
# 아식스젤카야노 외
# 러닝화 베스트 추천
# ...
