# %% [markdown]
# 1. 브런치 홈페이지에서 인기 글 제목을 수집하세요.
# 2. 구글 Scholar에서 'SEO Marketing' 논문 제목을 5개 수집하세요.
# 3. TIOBE Index 사이트에서 상위 10개 프로그래밍 언어 이름을 수집하세요.
# 4. 데이터마켓(data.go.kr)에서 '소비' 관련 공공데이터 제목을 10개 수집하세요.
# 5. 알라딘에서 '자기계발' 베스트 도서의 제목과 저자를 수집하세요.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://brunch.co.kr/"
driver.get(url)
time.sleep(2)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

titles = driver.find_elements(By.CSS_SELECTOR, "li.embla__slide.svelte-117s9qv strong.tit_subject")
for t in titles :
    print(t.text)

driver.quit()
# Out:
# 오늘, 엄마 빚을 다 갚았다.
# 어머니, 감자전 좀 그만 부쳐요
# 시어머니께 전화 안하는 며느리
# 아랫집도 공사 중인데 옆집도 공사해요.
# 김밥을 집에서 만들어 먹어야 하는 이유
# 매주 가는 시댁에 지쳤다

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://scholar.google.com/"
driver.get(url)
time.sleep(2)

Search = driver.find_element(By.CSS_SELECTOR, "input.gs_in_txt.gs_in_ac")
Search.clear()
Search.send_keys("SEO Marketing")
Search.send_keys(Keys.RETURN)

lists = driver.find_elements(By.XPATH, "//div[@id='gs_res_ccl_mid']//h3[@class='gs_rt']")
for l in lists[:6] :
    print(l.text)

driver.quit()
# Out:
# [책] Inbound marketing and SEO: Insights from the Moz Blog
# The role of search engine optimization in search marketing
# Application marketing strategy search engine optimization (SEO)
# [책] Optimize: How to attract and engage more customers by integrating SEO, social media, and content marketing
# [PDF] ¿ Marketing online?¿ SEO?¿ SEM? Conceptos básicos
# [책] SEO e SEM: guida avanzata al web marketing

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://www.tiobe.com/tiobe-index/"
driver.get(url)
time.sleep(2)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

rating = driver.find_elements(By.XPATH, "//table[@id='top20']//tbody//tr")
i = 1
for r in rating[:10] :
    rates = r.text.split()
    print(f"{i}위: {rates[2]}")
    i = i+1
driver.quit()
# Out:
# 1위: Python
# 2위: C++
# 3위: C
# 4위: Java
# 5위: C#
# 6위: JavaScript
# 7위: Visual
# 8위: Go
# 9위: Perl
# 10위: Delphi/Object

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://www.data.go.kr/index.do"
driver.get(url)
time.sleep(2)

searching = driver.find_element(By.XPATH, "//input[@id='keyword']")
searching.clear()
searching.send_keys("소비")
searching.send_keys(Keys.RETURN)
time.sleep(2)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(1)

result = driver.find_elements(By.CSS_SELECTOR, "div.result-list span.title")
for r in result[:10] :
    print(r.text)
# Out:
# 소득소비조사
# 인천광역시_소비 데이터
# 국토연구원_부동산시장 소비심리 정보
# 대전광역시 유성구_법정동별 소비금액 데이터
# 대전광역시 유성구_건당 평균 소비 데이터
# 농림축산식품부_우유 및 유제품 생산소비현황
# 제주특별자치도_단체/개별 관광객 소비 데이터
# 한국남부발전(주)_연료소비실적 정보
# 한국서부발전(주)_연료소비실적 조회서비스
# 한국중부발전(주)_연료소비실적 조회서비스

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

url = "https://www.aladin.co.kr/shop/wbrowse.aspx?CID=336&BrowseTarget=BestSeller"

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)
driver.get(url)
time.sleep(2)
books = driver.find_elements(By.XPATH, "//form[@id='Myform']//a[@class='bo']")
authors = driver.find_elements(By.XPATH, "//form[@id='Myform']//span[@class='gw']")

booklist = []

for a, b in zip(authors, books):
    booklist.append({"제목": b.text, "저자": a.text})
    
table = pd.DataFrame(booklist)

driver.quit()

table
# Out:
#                            제목                                  저자
# 0    고전이 답했다 마땅히 가져야 할 부에 대하여                         고명환 지음 | 라곰
# 1             열심히 살아도 불안한 사람들  랄리타 수글라니 지음, 박선령 옮김 | 알에이치코리아(RHK)
# 2                  미묘한 메모의 묘미                         김중혁 지음 | 유유
# 3                      듀얼 브레인            이선 몰릭 지음, 신동숙 옮김 | 상상스퀘어
# 4   매일 더 성장하고 싶은 당신을 위한 모닝 필사                         이재은 지음 | 책깃
# ..                        ...                                 ...
# 95                     가볍게 산다                     진민영 지음 | 책읽는고양이
# 96             나는 홀가분하게 살고 싶다                       이영길 지음 | 다산초당
# 97                 가난한 찰리의 연감   찰리 멍거 지음, 피터 코프먼 엮음, 김태훈 옮김 | 김영사
# 98            나의 돈 많은 고등학교 친구                        송희구 지음 | 서삼독
# 99               간다 마사노리의 대발견    간다 마사노리 지음, 전경아 옮김, 서승범 감수 | 더블북
#
# [100 rows x 2 columns]
