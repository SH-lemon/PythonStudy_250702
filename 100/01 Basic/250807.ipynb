# %% [markdown]
# - 마켓컬리에서 신상품 중 평점이 높은 10개 상품의 이름과 평점을 수집하세요.
# - G마켓에서 '게이밍 키보드' 검색 후 스크롤을 내려 상품명과 리뷰수를 수집하세요.
# - 11번가에서 '캠핑용품' 검색 후 가격 범위 필터 적용 후 상품명 수집하세요.
# - 크몽에서 '마케팅' 서비스 필터 조작 후 제목과 가격을 수집하세요.
# - GS샵에서 홈쇼핑 생방송 시간표를 스크롤로 수집하세요.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service=service, options=options)

url = "https://www.kurly.com/collection-groups/market-newproduct?page=1&collection=newranking1"
driver.get(url)
time.sleep(3)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(3)

titles = driver.find_elements(By.CSS_SELECTOR, "div.css-11kh0cw.ef36txc5 span.css-1dry2r1.e1c07x485")
reviews = driver.find_elements(By.CSS_SELECTOR, "div.css-11kh0cw.ef36txc5 span.review-number.css-l610kl.e1c07x480")

table01 = []
for t, r in zip(titles,reviews) :
    table01.append({"제품명":t.text,"리뷰수":r.text})

driver.quit()

table01[:10]
# Out:
# [{'제품명': '[켄트로얄] 헬로키티 에디션 성인/키즈 칫솔 10개입 2종 (택1)', '리뷰수': '16'},
#  {'제품명': '[도스타코스] 께사디야 2종', '리뷰수': '26'},
#  {'제품명': '아삭 복숭아 1.2kg [품종:오도로끼-(딱복)]', '리뷰수': '9,999+'},
#  {'제품명': '[일본디저트여행] 하카타 치도리야 티롤리안 6종 (택1)', '리뷰수': '11'},
#  {'제품명': '[바닐라코] 여행용 클린 잇 제로 오리지널 클렌징밤 트래블키트 3mL*16EA 4개 번들 기획 스누피 에디션 (+스누피 파우치, 스티커 증정)',
#   '리뷰수': '503'},
#  {'제품명': '[양산도] 나고야식 양념민물장어', '리뷰수': '54'},
#  {'제품명': '[Kiri] 베이크 치즈타르트 (40gX5개입)', '리뷰수': '11'},
#  {'제품명': '[훌랄라치킨] 숯불양념치킨with우동사리 670g', '리뷰수': '327'},
#  {'제품명': '[일본디저트여행] 치도리야 티롤리안 컬렉션 18개입', '리뷰수': '171'},
#  {'제품명': '[로로멜로] 아이스 브륄레 80g 4종(택1)', '리뷰수': '12'}]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service=service, options=options)

url = "https://www.gmarket.co.kr/n/search?keyword=%EA%B2%8C%EC%9D%B4%EB%B0%8D+%ED%82%A4%EB%B3%B4%EB%93%9C"
driver.get(url)
time.sleep(3)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(3)

titles = driver.find_elements(By.XPATH, "//div[@class='section__module-wrap']//span[@class='text__item']")
reviews = driver.find_elements(By.CSS_SELECTOR, "li.list-item.list-item__feedback-count > li.text")

ReviewTable = []

for t, r in zip(titles,reviews) :
    append.ReviewTable({"상품명":t.text.strip(),"리뷰수":r.text.strip()})

Reviewstable = pd.DataFrame(ReviewTable)

driver.quit()

Reviewstable
# G마켓이 잠겼습니다 :(
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service=service, options=options)

url = "https://search.11st.co.kr/pc/total-search?kwd=%25EC%25BA%25A0%25ED%2595%2591%25EC%259A%25A9%25ED%2592%2588&tabId=TOTAL_SEARCH&toPrice=42800"
driver.get(url)
time.sleep(3)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(3)

titles = driver.find_elements(By.XPATH, "//ul[@class='c-search-list__container']//a[@class='c-card-item__anchor']//span[@class='sr-only']")
for t in titles:
    print(t.text)

driver.quit()
# Out:
# [리베로] 1+1 봄맞이 캠핑의자 모음전
# 캠프듀아 액화방지 2가지 불조절 요리용 토치
# 부탄가스 맥스부탄가스220g(28개)1박스
# 팔팔장작 참나무장작 캠핑 바베큐 미니 사이즈 10kg 15kg
# 화산 쎈연료 야외용 캠핑용 고화력 부탄가스 220g 한박스 28개
# 바베큐 참숯 700g 1박스(20EA/착화제 중량 포함) 숯 차콜 구이용숯 캠핑숯 바베큐용숯 바베큐용 봉지숯
# 참숯 숯불구이용 바베큐 대용량 캠핑 펜션 업소 야외용 벌크 18kg / 소분포장 16kg
# 웰빙 원터치 바베큐 숯 100% 천연나무 숯 1kg
# 대상참숯 숯불구이 바베큐 대용량 캠핑 펜션 업소용 야외용 벌크형 20kg
# 카르닉 4단 투웨이 랜턴스탠드 무광 랜턴걸이 거치대 삼각대 이동식 스크린삼각대
# 부르스타기획전 고화력 휴대용가스렌지 가스버너 미니렌지 캠핑 취사용품 식당 가정
# [리베로] 1+1 봄맞이 캠핑의자 모음전
# 꾸버스 일회용 석쇠 태망 사각 원형 석쇠 바베큐그릴 캠핑 야외 숯불 펜션 식당 업소 도매
# NEW 양면형 훈제 바베큐그릴 휴대용 캠핑 숯불그릴 불판 화로대
# 캠프듀아 액화방지 2가지 불조절 요리용 토치
# HONEST 충전식 가스토치 터보라이터 원터치 마이크로토치 500JET
# 카르닉 스테인리스 캠핑 식기세트 경질코펠 그리들 버너바람막이 설거지통 건조망 모음
# 부탄가스 맥스부탄가스220g(28개)1박스
# 일본식 미니화로 라운드 구이팬 세트 가정용 개인 화로 캠핑용 1인용 불판
# 쿨조끼 아이스조끼 세트 작업복 7시간냉기지속 얼음 쿨자켓 쿨아이스 여름자켓
# 팔팔장작 참나무장작 캠핑 바베큐 미니 사이즈 10kg 15kg
# 뷔페 보온용 고체연료 250g 1캔 미니화로 착화체 캠핑 불쏘시개
# 카르닉 캠핑 설거지통 28L 건조망세트 다용도 씽크볼 세차바구니 멀티바스켓 캠핑용품
# 화산 쎈연료 야외용 캠핑용 고화력 부탄가스 220g 한박스 28개
# 캠핑 캠프파이어 불멍 화목 벽난로 참나무 장작 20kg
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service=service, options=options)

url = "https://kmong.com/category/217"
driver.get(url)
time.sleep(3)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(3)

titles = driver.find_elements(By.CSS_SELECTOR, "div.css-1sp7pnt.e1ueu6sa1 div.flex.flex-col.gap-1")
costs = driver.find_elements(By.XPATH, "//div[contains(@class, 'text-[14px]') and contains(text(), '원')]")

table00 = []
for t, c in zip(titles, costs):
    table00.append({"제목": t.text, "가격": c.text})

table0 = pd.DataFrame(table00)

driver.quit()

table0
# Out:
#                                 제목           가격
# 0   무작정 글 쓰는 시대는 끝ㅣ 브랜딩 최적화 블로그 관리    290,000원~
# 1        N년차 자영업 전문 블로그관리 성공신화 서비스    275,000원~
# 2   블로그관리 브랜드포스팅대행 브랜드블로그 마케팅 AI아님    264,000원~
# 3        PREMIUM 실력으로 핫한 블로그관리 서비스    375,000원~
# 4          블로그 방문자 조회수 고가치 트래픽 최적화      5,000원~
# 5     병원블로그관리 병원광고 신환이 올때까지 마케팅합니다  1,100,000원~
# 6               브랜드를 키우는, 블로그 관리대행    159,000원~
# 7         높은 재계약률 블로그 관리 홈페이지형 블로그    159,000원~
# 8   블로그대행관리 최적화전문가 포스팅 개인 회사 원고 배포    219,000원~
# 9      블로그대행 브랜딩블로그 블로그컨설팅 블로그관리대행    400,000원~
# 10  블로그관리 브랜드블로그 전문가가 맞춤형 관리해드립니다.    220,000원~
# 11      병의원 전문 블로그 관리, 브랜딩에 진심입니다.    600,000원~
# 12       블로그관리 맞춤형으로 최적화 운영 해드립니다.    220,000원~
# 13    블로그대행 블로그관리 블로그마케팅 검색형 블로그운영    189,000원~
# 14             병원 브랜드 블로그만 관리해드립니다    400,000원~
# 15     이웃관리를 편하게 셀프로 할 수 있는 솔루션입니다     25,000원~
# 16   블로그 실제유저로 블로그이웃 활성화 블로그 이웃 관리     50,000원~
# 17     블로그 관리,제작 일대일 맞춤형 관리해 드립니다.    130,000원~
# 18   병원 마케팅, 병원 블로그 마케팅, 병원 블로그 관리     10,000원~
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://www.gsshop.com/shop/tv/tvScheduleMain.gs?lseq=415680-1&gsid=ECmain-AU415680-AU415680-1"

driver.get(url)
time.sleep(2)

timetable = []

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

times = driver.find_elements(By.XPATH, "//section[@id='onair-Schedule']//span[@class='times']")
products = driver.find_elements(By.XPATH, "//section[@id='onair-Schedule']//li[@class='prd-item']//dt[@class='prd-name']")

for t, p in zip(times, products) :
    timetable.append({"시간":t.text, "제품":p.text})

table = pd.DataFrame(timetable)

driver.quit()

table
# Out:
#        시간                                                 제품
# 0   01:00               [TV상품] [싱글] 파워캡슐 소프트엑스 블랑머스크 6팩+본품1팩
# 1   02:00              [TV상품] [더블] 파워캡슐 소프트엑스 블랑머스크 12팩+본품2팩
# 2   02:40      [TV상품] 라삐아프 25SS 썸머 테이퍼드팬츠 3종 [런칭 가격 79,900원]
# 3   03:20    [TV상품] 롱)라삐아프 25SS 썸머 테이퍼드팬츠 3종 [런칭 가격 79,900원]
# 4   04:00    [TV상품] SJ와니 25SS 텐션 반바지 1종 (골프) [런칭 가격 79,900원]
# 5   04:40  [TV상품] SJ와니 25SS 에어리 슬리브리스 니트 1종(골프) [런칭 가격 59...
# 6   05:30  [TV상품] SJ와니 25SS 사브리나 크롭 팬츠 1종(골프) [런칭 가격 79,9...
# 7   06:00  [TV상품] SJ와니 25SS 사브리나 크롭 팬츠 1종-플라워(골프) [런칭 가격 ...
# 8   07:15      [TV상품] SJ와니 25SS 리조트 시어 점퍼 1종 [런칭 가격 99,900원]
# 9   08:15      [TV상품] 라삐아프 25SS 썸머 테이퍼드팬츠 3종 [런칭 가격 79,900원]
# 10  09:25    [TV상품] 롱)라삐아프 25SS 썸머 테이퍼드팬츠 3종 [런칭 가격 79,900원]
# 11  10:25        [TV상품] SJ와니 25SS 플리츠 풀오버 3종 [런칭 가격 89,900원]
# 12  11:35    [TV상품] SJ와니 25SS 리조트 그레이스 팬츠 1종 [런칭 가격 79,900원]
# 13  12:35  [TV상품] SJ와니 25SS 린넨 와이드 데님팬츠 1종 (라이크라) [런칭 가격 ...
# ...
