# %% [markdown]
# * 구글 뉴스에서 'ChatGPT' 관련 기사 제목을 수집하세요.
# * 서울시청 홈페이지에서 공지사항 제목 10개를 수집하세요.
# * 쿠팡에서 '노트북' 검색결과의 리뷰 수가 100개 이상인 상품만 수집하세요.
# * 인스타그램에 로그인 후 '#여행' 해시태그로 게시물 20개의 텍스트를 수집하세요.
# * 트위터 로그인 후 '#디지털마케팅' 트윗 50개의 텍스트를 수집하세요.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://news.google.com/home?hl=ko&gl=KR&ceid=KR%3Ako"
driver.get(url)
time.sleep(2)

search = driver.find_element(By.CSS_SELECTOR, "input.Ax4B8.ZAGvjd")
search.clear()
search.send_keys("ChatGPT")
search.send_keys(Keys.RETURN)
time.sleep(2)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

titles = driver.find_elements(By.CSS_SELECTOR, "c-wiz.D9SJMe a.JtKRv")
for t in titles[:10] :
    print(t.text)

driver.quit()
# Out:
# ChatGPT, ‘건강한 사용’을 위한 기능 업데이트
# ChatGPT가 근본적으로 바뀌고 있습니다! 더 많은 휴식 시간과 민감한 주제에 대한 새로운 답변이 추가되었습니다.
# AI 실무 자동화 교육 수요 증가…세미나허브, ‘AI+ChatGPT 실전 클래스’ 3차 교육 개최
# 공부 모드를 소개합니다
# ChatGPT 활용한 과학 논문 작성 증가…컴퓨터 과학 분야 두드러져
# 수시모집 ChatGPT 생기부세특 마사지대회?…학생수업활동 교사정리 후 대학면접평가 타당
# AI 시대 준비하는 한국장애인고용공단, ChatGPT 교육 성료
# ChatGPT Weekly Active Users Expected to Surpass 700 Million — A Fourfold Surge from Last Year
# 오픈AI '챗GPT', 이미지 생성 기능 힘입어 주간 사용자 7억 명 돌파 임박
# ChatGPT에서 충격적인 발견이 사용자를 놀라게 했다

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://www.seoul.go.kr/main/index.jsp"
driver.get(url)
time.sleep(2)

news = driver.find_element(By.XPATH, "//a[@href='/realmnews/in/list.do']")
news.click()
time.sleep(2)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

titles = driver.find_elements(By.CSS_SELECTOR, "div.news-lst em.subject")
for t in titles[:10] :
    print(t.text)

driver.quit()
# Out:
# (추천명단)(#남양주)'왕숙 푸르지오 더 퍼스트' 서울시 장애인 특별공급 기관추천 명단
# 아이 태어난 무주택 가구에 최대 720만 원 주거비 드려요('25.10.31.까지 신청)
# 돌아오는 뮤지컬 <어쩌면 해피엔딩>, 서울청년문화패스로 볼까?
# 외국인 택시 불법행위 근절 나선다…100일 현장 집중단속
# 서울시 동행 의료통역지원단 운영 사업 안내
# [2025년 8월호] 조류인플루엔자의 스필오버: 조용히 퍼지는 팬데믹의 전조
# 물놀이형 수경시설 수질검사 결과(2025년 7월)
# 8.9(토)부터 하남시 지하철에서도 편리하게 `기후동행카드` 이용하세요
# (추천명단)(#화성)'화성동탄2 C14블록(뉴홈 선택형)' 서울시 장애인 특별공급 기관추천 명단
# 장바구니 물가를 잡아라… 서울시, 역대급 폭염에 시금치 7천 단 약 57% 할인

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url = "https://www.coupang.com/"
driver.get(url)
time.sleep(2)

search = driver.find_element(By.XPATH, "//input[@placeholder='찾고 싶은 상품을 검색해보세요!']")
search.send_keys("노트북")
time.sleep(1)
search.send_keys(Keys.RETURN)
time.sleep(2)

driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

prods = driver.find_elements(By.CSS_SELECTOR, "div.ProductUnit_productName__gre7e")

for p in prods[:10] :
    p.click()
    time.sleep(2)
    reviews = driver.find_element(By.CSS_SELECTOR, "span.rating-count-txt.twc-text-[12px].lg:twc-text-[14px]")
    r = reviews.text
    r.strip(" ")
    if len(r) >=7 :
        print(p.text)

driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import time

service = Service(ChromeDriverManager().install())
options = Options()
options.add_argument('--disable-dev-shm-usage')
options.add_argument('--window-size=1920x1080')
options.add_argument('--start-maximized')
options.add_argument('--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.')
options.add_argument('--lang=ko_KR')

driver = webdriver.Chrome(service = service, options = options)

url =
