# %% [markdown]
# #### 종합 과제: “충성 사용자 & 영화 인사이트 리포트”
# 영화 서비스의 이용자·댓글·영화 데이터를 바탕으로, 마케팅팀이 바로 사용할 수 있는 두 가지 리포트를 만들어 주세요.
#  결과는 각각 별도의 출력 구조로 제출합니다.
# ```
# 1) 충성 사용자 리포트
#
# 이용자와 댓글 데이터를 결합해, 총 댓글 수가 10개 이상인 이용자만 추립니다.
# 각 이용자에 대해 다음 지표를 계산해 주세요:
#
# commentsCount(총 댓글 수)
# avgTextLen(댓글 평균 길이, null/missing은 길이 0으로 간주)
# lastCommentDate(가장 최근 댓글 시점)
# 결과에는 **이름(name), 이메일(email)**만 식별 정보로 포함하고, 위 활동 지표 **내림차순(많이·길게·최근 순)**으로 정렬해 상위 이용자가 누구인지 한눈에 보이도록 합니다.
#
# 2) 영화 인사이트 리포트
#
# 영화 컬렉션만으로 한 번의 파이프라인에서 다음을 동시에 산출해 주세요.
#
# * 최신 영화 5편: 제목(title)과 연도(year) 목록
# * 고평점 영화 개수: imdb.rating ≥ 8 작품의 총 개수(숫자 1개)
# * 장르별 상위 10: 장르별 작품 수를 집계해 상위 10개를 많이 나온 순으로 정렬
# * 연도별 평균 평점(최근 10년): 최신 연도를 기준으로 최근 10개 연도의 평균 평점을 산출(연도-오름차순 표기)
#
# 출력 형식 가이드
# 충성 사용자 리포트: 리스트(배열) 형태. 각 원소는 {name, email, commentsCount, avgTextLen, lastCommentDate}.
# 영화 인사이트 리포트: 단일 문서(오브젝트) 형태.
# 키는 latest5, highRatedCount, genresTop10, yearlyAvgRecent10로 구성.
# highRatedCount는 숫자 하나로 제출
# ```

# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")

db = client.sample_mflix

# %%
movies = db.movies
users = db.users
comments = db.comments

# %%
# 1) 충성 사용자 리포트
pipeline = [
    {"$lookup": {
        "from": "comments",
        "localField": "email",
        "foreignField": "email",
        "as": "userComments"
    }},
    {"$unwind": "$userComments"},
    {"$group": {
        "_id": { "name": "$name", "email": "$email" },
        "commentsCount": { "$sum": 1 },
        "avgTextLen": { "$avg": { "$strLenCP": "$userComments.text" } },
        "lastCommentDate": { "$max": "$userComments.date" } 
    }},
    {"$sort": { "commentsCount": -1, "avgTextLen": -1, "lastCommentDate": -1 }},
    {"$project": { "_id": 1}}
]

for user in users.aggregate(pipeline):
    print(f"name: {user['_id']['name']} / email: {user['_id']['email']}")
# Out:
# name: Mace Tyrell / email: roger_ashton-griffiths@gameofthron.es
# name: Missandei / email: nathalie_emmanuel@gameofthron.es
# name: The High Sparrow / email: jonathan_pryce@gameofthron.es
# name: Sansa Stark / email: sophie_turner@gameofthron.es
# name: Rodrik Cassel / email: ron_donachie@gameofthron.es
# name: Thoros of Myr / email: paul_kaye@gameofthron.es
# name: Robert Jordan / email: robert_jordan@fakegmail.com
# name: Brienne of Tarth / email: gwendoline_christie@gameofthron.es
# name: Kathryn Sosa / email: kathryn_sosa@fakegmail.com
# name: Mrs. Ariana Nunez / email: mrs._ariana_nunez@fakegmail.com
# name: Shireen Baratheon / email: kerry_ingram@gameofthron.es
# name: Rast / email: luke_barnes@gameofthron.es
# name: Sandor Clegane / email: rory_mccann@gameofthron.es
# name: Garrett Obrien / email: garrett_obrien@fakegmail.com
# name: Davos Seaworth / email: liam_cunningham@gameofthron.es
# name: Paul Bailey / email: paul_bailey@fakegmail.com
# name: Maester Aemon / email: peter_vaughan@gameofthron.es
# name: Taylor Hill / email: taylor_hill@fakegmail.com
# name: Myrcella Baratheon / email: nell_tiger_free@gameofthron.es
# name: Roose Bolton / email: michael_mcelhatton@gameofthron.es
# name: Richard Davis / email: richard_davis@fakegmail.com
# name: Anthony Thompson / email: anthony_thompson@fakegmail.com
# name: Lori Blankenship / email: lori_blankenship@fakegmail.com
# name: Blake Fitzgerald / email: blake_fitzgerald@fakegmail.com
# name: Joffrey Baratheon / email: jack_gleeson@gameofthron.es
# name: Meryn Trant / email: ian_beattie@gameofthron.es
# name: April Cole / email: april_cole@fakegmail.com
# name: Thomas Morris / email: thomas_morris@fakegmail.com
# name: Jeor Mormont / email: james_cosmo@gameofthron.es
# name: Khal Drogo / email: jason_momoa@gameofthron.es
# name: Thomas Buckley / email: thomas_buckley@fakegmail.com
# name: The Waif / email: faye_marsay@gameofthron.es
# name: Grey Worm / email: jacob_anderson@gameofthron.es
# name: Mary Mitchell / email: mary_mitchell@fakegmail.com
# name: Donna Russell / email: donna_russell@fakegmail.com
# name: Melissa Young / email: melissa_young@fakegmail.com
# name: Jose Hall / email: jose_hall@fakegmail.com
# name: Ashlee Hart / email: ashlee_hart@fakegmail.com
# name: Lisa Russo / email: lisa_russo@fakegmail.com
# name: Selyse Baratheon / email: tara_fitzgerald@gameofthron.es
# name: Jaqen H'ghar / email: tom_wlaschiha@gameofthron.es
# name: Ygritte / email: rose_leslie@gameofthron.es
# name: Anthony Cline / email: anthony_cline@fakegmail.com
# name: Ned Stark / email: sean_bean@gameofthron.es
# name: Heather Leonard / email: heather_leonard@fakegmail.com
# name: Lisa Silva / email: lisa_silva@fakegmail.com
# name: Jorah Mormont / email: iain_glen@gameofthron.es
# name: Ros / email: esme_bianco@gameofthron.es
# name: Kimberly Gates / email: kimberly_gates@fakegmail.com
# name: Ramsay Bolton / email: iwan_rheon@gameofthron.es
# name: Theon Greyjoy / email: alfie_allen@gameofthron.es
# name: Robb Stark / email: richard_madden@gameofthron.es
# name: Julia Nichols / email: julia_nichols@fakegmail.com
# name: Daario Naharis / email: michiel_huisman@gameofthron.es
# name: Samwell Tarly / email: john_bradley-west@gameofthron.es
# name: Amy Phillips / email: amy_phillips@fakegmail.com
# name: Kelsey Smith / email: kelsey_smith@fakegmail.com
# name: Morgan Smith / email: morgan_smith@fakegmail.com
# name: Doreah / email: roxanne_mckee@gameofthron.es
# name: Osha / email: natalia_tena@gameofthron.es
# name: Varys / email: conleth_hill@gameofthron.es
# name: Alliser Thorne / email: owen_teale@gameofthron.es
# name: Pypar / email: josef_altin@gameofthron.es
# name: Karina Martin / email: karina_martin@fakegmail.com
# name: Jordan Medina / email: jordan_medina@fakegmail.com
# name: Meera Reed / email: ellie_kendrick@gameofthron.es
# name: Jon Snow / email: kit_harington@gameofthron.es
# name: Jamie Santana / email: jamie_santana@fakegmail.com
# name: Jennifer Frazier / email: jennifer_frazier@fakegmail.com
# name: Irri / email: amrita_acharia@gameofthron.es
# name: Emily Ellis / email: emily_ellis@fakegmail.com
# name: Christopher Robinson / email: christopher_robinson@fakegmail.com
# name: Jerry Cabrera / email: jerry_cabrera@fakegmail.com
# name: Bowen Marsh / email: michael_condron@gameofthron.es
# name: Yolanda Owen / email: yolanda_owen@fakegmail.com
# name: Victor Patel / email: victor_patel@fakegmail.com
# name: Cersei Lannister / email: lena_headey@gameofthron.es
# name: Taylor Scott / email: taylor_scott@fakegmail.com
# name: Barristan Selmy / email: ian_mcelhinney@gameofthron.es
# name: Connie Johnson / email: connie_johnson@fakegmail.com
# name: 홍길동 / email: hong@test.com

# %%
# 2) 영화 인사이트 리포트

pipeline = [
    {"$facet": {
        "latest5": [
            {"$sort": {"released": -1}},
            {"$project": {"_id": "$title", "year": 1}},
            {"$limit": 5}
        ],
        "highRatedCount": [
            {"$match": {"imdb.rating": {"$gte": 8}}},
            {"$count": "HighRatedCount"}
        ],
        "genresTop10": [
            {"$unwind": "$genres"},
            {"$group": {"_id": "$genres", "movieCount": {"$sum": 1}}},
            {"$sort": {"movieCount": -1}},
            {"$limit": 10}
        ],
        "yearlyAvgRecent10": [
            {"$group": {"_id": "$year", "avgRating": {"$avg": "$imdb.rating"}}},
            {"$sort": {"_id": -1}},
            {"$limit": 10}
        ]
    }}
]

for movie in movies.aggregate(pipeline):
    print("=== Latest 5 ===")
    for m in movie['latest5']:
        print(f"{m['_id']} ({m['year']})")

    print("\n=== High Rated Count ===")
    print(movie['highRatedCount'][0]['HighRatedCount'])

    print("\n=== Top 10 Genres ===")
    for o in movie['genresTop10']:
        print(f"{o['_id']}: {o['movieCount']}")

    print("\n=== Yearly Avg Recent 10 ===")
    for v in movie['yearlyAvgRecent10']:
        print(f"{v['_id']} : {v['avgRating']}")
# Out:
# === Latest 5 ===
# The Treasure (2015)
# Knight of Cups (2015)
# Sand Castles (2014)
# Shut In (2015)
# Dègradè (2015)
#
# === High Rated Count ===
# 1596
#
# === Top 10 Genres ===
# Drama: 13789
# Comedy: 7024
# Romance: 3665
# Crime: 2678
# Thriller: 2658
# Action: 2539
# Documentary: 2129
# Adventure: 2045
# Horror: 1703
# Biography: 1404
#
# === Yearly Avg Recent 10 ===
# 2015è : 8.4
# 2014è : 7.25
# 2012è : 7.5
# 2011è : 7.75
# 2010è : 8.2
# 2009è : 8.3
# 2007è : 8.533333333333333
# 2006è2012 : 8.5
# 2006è2007 : 9.0
# 2006è : 7.2
