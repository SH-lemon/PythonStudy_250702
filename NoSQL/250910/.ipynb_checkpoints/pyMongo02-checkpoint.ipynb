# %%
from pymongo import MongoClient

client = MongoClient("mongodb://localhost:27017")

db = client.sample_mflix
movies = db.movies

print(movies)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'sample_mflix'), 'movies')

# %%
# find() => aggregation Framework 문법을 사용하면 pipeline 생성해서 복잡한 데이터처리를 순차적으로

# 1. $match => 특정조건에 해당되는 문서를 찾아오고자 할 때
# 2. $limit => find()limit() 동일한 기능

for movie in movies.aggregate([{"$match": {"genres": "Action"}}, {"$limit": 1}]) :
    print(movie)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd5293'), 'plot': "Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle's secretary has been named as her guardian until she marries, at which time she will officially take ...", 'genres': ['Action'], 'runtime': 199, 'cast': ['Pearl White', 'Crane Wilbur', 'Paul Panzer', 'Edward Josè'], 'num_mflix_comments': 1, 'poster': 'https://m.media-amazon.com/images/M/MV5BMzgxODk1Mzk2Ml5BMl5BanBnXkFtZTgwMDg0NzkwMjE@._V1_SY1000_SX677_AL_.jpg', 'title': 'The Perils of Pauline', 'fullplot': 'Young Pauline is left a lot of money when her wealthy uncle dies. However, her uncle\'s secretary has been named as her guardian until she marries, at which time she will officially take possession of her inheritance. Meanwhile, her "guardian" and his confederates constantly come up with schemes to get rid of Pauline so that he can get his hands on the money himself.', 'languages': ['English'], 'released': datetime.datetime(1914, 3, 23, 0, 0), 'directors': ['Louis J. Gasnier', 'Donald MacKenzie'], 'writers': ['Charles W. Goddard (screenplay)', 'Basil Dickey (screenplay)', 'Charles W. Goddard (novel)', 'George B. Seitz', 'Bertram Millhauser'], 'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'}, 'lastupdated': '2015-09-12 00:01:18.647000000', 'year': 1914, 'imdb': {'rating': 7.6, 'votes': 744, 'id': 4465}, 'countries': ['USA'], 'type': 'movie', 'tomatoes': {'viewer': {'rating': 2.8, 'numReviews': 9}, 'production': 'Pathè Frères', 'lastUpdated': datetime.datetime(2015, 9, 11, 17, 46, 19)}}

# %%
# $group : SQL에서의 GROUP BY 와 동일한 기능

for movie in movies.aggregate([{"$group": {"_id": "$directors", "count":{"$sum":1}}, }, {"$limit": 1}]) :
    print(movie)
# Out:
# {'_id': ['Ole Gièver'], 'count': 1}

# %%
pipeline = [
    {"$sort": {"title": 1}}, {"$limit": 3},
    {"$project": {"_id": 0, "title": 1, "genres"}}
]

for movie in movies.aggregate(pipeline) :
    print(movie)
# Out:
# {'genres': ['Documentary'], 'title': 1}
# {'genres': ['Sci-Fi', 'Thriller'], 'title': 1}
# {'genres': ['Comedy', 'Drama', 'Romance'], 'title': 3}

# %%
# $unwind : 배열 안에 입력된 값을 추출해서 출력하고자 할 때
for movie in movies.aggregate([{"$unwind": "$genres"}, {"$group": {"_id": "genres", "count": {"$sum":1}}}, {"$limit":3}]) :
    print(movie)
# Out:
# {'_id': 'genres', 'count': 49781}

# %%
# $group & 집계연산자 응용 패턴
pipeline = [
    {"$group": {"_id": "$directors", "count": {"$sum":1}}},
    {"$limit": 5}
]
for movie in movies.aggregate(pipeline) :
    print(movie)
# Out:
# {'_id': ['Dorothèe Van Den Berghe'], 'count': 2}
# {'_id': ['Ash Adams'], 'count': 1}
# {'_id': ['Mervyn LeRoy'], 'count': 16}
# {'_id': ['R. Balki'], 'count': 2}
# {'_id': ['Richard Bell'], 'count': 1}

# %%
pipeline = [
    {"$group": {"_id": "$directors", "avg_rating": {"$avg":"$imdb.rating"}}}
]
for movie in movies.aggregate(pipeline) :
    print(movie)
# Out:
# {'_id': ['Ole Gièver'], 'avg_rating': 5.7}
# {'_id': ['Dwayne Carey-Hill'], 'avg_rating': 7.5}
# {'_id': ['Stefan Prehn', 'Jèrg Wagner'], 'avg_rating': 8.0}
# {'_id': ['Toshiaki Toyoda'], 'avg_rating': 7.425000000000001}
# {'_id': ['Jan Verheyen', 'Pieter Van Hees'], 'avg_rating': 5.9}
# {'_id': ['Brian Percival'], 'avg_rating': 7.6}
# {'_id': ['Rob Letterman', 'Conrad Vernon'], 'avg_rating': 6.6}
# {'_id': ['Michael Curtiz', 'John Wayne'], 'avg_rating': 6.9}
# {'_id': ['R. Kelly', 'Victor Mignatti', 'Jim Swaffield'], 'avg_rating': 6.5}
# {'_id': ['Young-Tak Kim'], 'avg_rating': 7.7}
# {'_id': ['Diederik Ebbinge'], 'avg_rating': 7.1}
# {'_id': ['Josef Kubota Wladyka'], 'avg_rating': 7.1}
# {'_id': ['Cem Yilmaz'], 'avg_rating': 8.0}
# {'_id': ['Anna Chi'], 'avg_rating': 5.2}
# {'_id': ['Julius Sevcèk'], 'avg_rating': 6.15}
# {'_id': ['Ann Turner'], 'avg_rating': 5.8}
# {'_id': ['Andi Rogenhagen'], 'avg_rating': 6.8}
# {'_id': ['Mikael Salomon'], 'avg_rating': 6.0200000000000005}
# {'_id': ['Cam Archer'], 'avg_rating': 5.95}
# {'_id': ['Eduardo Sènchez'], 'avg_rating': 5.25}
# {'_id': ['Vasiliy Shukshin'], 'avg_rating': 8.0}
# {'_id': ['Adriano Celentano', 'Miky Del Prete'], 'avg_rating': 6.2}
# {'_id': ['Katherine Dieckmann'], 'avg_rating': 4.6}
# {'_id': ['Artus de Penguern'], 'avg_rating': 6.9}
# {'_id': ['Albert Xavier'], 'avg_rating': 5.5}
# {'_id': ['Ivan Dykhovichnyy'], 'avg_rating': 6.9}
# {'_id': ['èdèm Csèszi'], 'avg_rating': 6.9}
# {'_id': ['Kompin Kemgumnird'], 'avg_rating': 6.1}
# {'_id': ['Jovan B. Todorovic'], 'avg_rating': 6.9}
# {'_id': ['Justin Schwarz'], 'avg_rating': 5.6}
# {'_id': ['Brenda Chapman', 'Steve Hickner', 'Simon Wells'], 'avg_rating': 7.0}
# {'_id': ['Vanessa Roth'], 'avg_rating': None}
# {'_id': ['Janne Kuusi'], 'avg_rating': 6.35}
# {'_id': ['Dino Risi'], 'avg_rating': 6.81875}
# {'_id': ['Don Argott', 'Demian Fenton'], 'avg_rating': 7.5}
# {'_id': ['Alfred L. Werker'], 'avg_rating': 7.0}
# {'_id': ['Dave Meyers'], 'avg_rating': 5.6}
# {'_id': ['Franck Khalfoun'], 'avg_rating': 6.0}
# {'_id': ['Diederick Koopal'], 'avg_rating': 7.45}
# {'_id': ['Ana Guevara', 'Leticia Jorge'], 'avg_rating': 6.3}
# {'_id': ['Kèzaburè Yoshimura'], 'avg_rating': 7.4}
# {'_id': ['Wu Jing'], 'avg_rating': 5.6}
# {'_id': ['Vincent Foster'], 'avg_rating': 2.3}
# {'_id': ['Jay DiPietro'], 'avg_rating': 6.3}
# {'_id': ['Jonathan Liebesman'], 'avg_rating': 5.683333333333334}
# {'_id': ['Gina Kim'], 'avg_rating': 6.4}
# {'_id': ['Valerio Jalongo'], 'avg_rating': 5.6}
# {'_id': ['Carl Franklin'], 'avg_rating': 6.683333333333334}
# {'_id': ['Alan Poul'], 'avg_rating': 5.2}
# {'_id': ['Sophie Huber'], 'avg_rating': 7.3}
# {'_id': ['Ali Samadi Ahadi'], 'avg_rating': 7.6}
# {'_id': ['Rick Rowley'], 'avg_rating': 7.5}
# {'_id': ['Jean-Loup Hubert'], 'avg_rating': 6.8}
# {'_id': ['Andrzej Celinski', 'Hanna Polak'], 'avg_rating': 8.0}
# {'_id': ['Marco Bellocchio', 'Bernardo Bertolucci', 'Jean-Luc Godard', 'Carlo Lizzani', 'Pier Paolo Pasolini', 'Elda Tattoli'], 'avg_rating': 6.0}
# {'_id': ['Ranald MacDougall'], 'avg_rating': 7.0}
# {'_id': ['Graeme Campbell'], 'avg_rating': 6.4}
# {'_id': ['Byeong-ki Ahn'], 'avg_rating': 6.0}
# {'_id': ['Yeon-Shick Shin'], 'avg_rating': 6.8}
# {'_id': ['Edith Becker', 'Kevin Burns'], 'avg_rating': 8.4}
# {'_id': ['Lance Hool'], 'avg_rating': 6.1}
# {'_id': ['Scott Graham'], 'avg_rating': 6.4}
# {'_id': ['Felix Fuchssteiner'], 'avg_rating': 6.1}
# {'_id': ['Suzie Templeton'], 'avg_rating': 7.7}
# {'_id': ['Scott Hicks'], 'avg_rating': 6.914285714285714}
# {'_id': ['A.R. Murugadoss'], 'avg_rating': 6.975}
# {'_id': ['Desmond Davis'], 'avg_rating': 6.95}
# {'_id': ['Wiktor Grodecki'], 'avg_rating': 5.45}
# {'_id': ['Byambasuren Davaa', 'Luigi Falorni'], 'avg_rating': 7.5}
# {'_id': ['Heitor Dhalia'], 'avg_rating': 7.1}
# {'_id': ['Ian McCluskey'], 'avg_rating': 8.3}
# {'_id': ['Lauren Montgomery'], 'avg_rating': 7.35}
# {'_id': ['James Hayman'], 'avg_rating': 6.25}
# {'_id': ['Caradog W. James'], 'avg_rating': 6.1}
# {'_id': ['Nelson George', 'Diane Paragas'], 'avg_rating': 8.0}
# {'_id': ['Stacy Cochran'], 'avg_rating': 5.6}
# {'_id': ['Steve Reeves'], 'avg_rating': 5.5}
# {'_id': ['Diederik Van Rooijen'], 'avg_rating': 7.0}
# {'_id': ['Sean Baker'], 'avg_rating': 6.933333333333334}
# {'_id': ['C.M. Talkington'], 'avg_rating': 6.0}
# {'_id': ['Sean Meredith'], 'avg_rating': 6.6}
# {'_id': ['Nadir Moknèche'], 'avg_rating': 6.8}
# {'_id': ['George P. Cosmatos', 'Kevin Jarre'], 'avg_rating': 7.8}
# {'_id': ['Ira Sachs'], 'avg_rating': 6.333333333333333}
# {'_id': ['Sabine Gisiger'], 'avg_rating': 6.7}
# {'_id': ['I.V. Sasi'], 'avg_rating': 8.2}
# {'_id': ['Sara Johnsen'], 'avg_rating': 6.55}
# {'_id': ['Lloyd Bacon'], 'avg_rating': 7.159999999999999}
# {'_id': ['Martial Fougeron'], 'avg_rating': 6.7}
# {'_id': ['Aaron Rose', 'Joshua Leonard'], 'avg_rating': 7.1}
# {'_id': ['Andrè Tèchinè'], 'avg_rating': 6.66875}
# {'_id': ['Liz W. Garcia'], 'avg_rating': 5.7}
# {'_id': ['Bill Eagles'], 'avg_rating': 5.9}
# {'_id': ['Timo Vuorensola'], 'avg_rating': 5.9}
# {'_id': ['Regardt van den Bergh'], 'avg_rating': 7.0}
# {'_id': ['Saverio Costanzo'], 'avg_rating': 6.533333333333334}
# {'_id': ['Damon Santostefano'], 'avg_rating': 5.9}
# {'_id': ['Richard Friedenberg'], 'avg_rating': 6.6000000000000005}
# {'_id': ['Chris Fiore'], 'avg_rating': 5.5}
# {'_id': ['Steve Gomer'], 'avg_rating': 2.8}
# {'_id': ['Per Berglund'], 'avg_rating': 5.7}
# {'_id': ['Lisa Mulcahy'], 'avg_rating': 6.9}
# {'_id': ['Satoshi Miki'], 'avg_rating': 6.8}
# {'_id': ['Hari'], 'avg_rating': 6.9}
# {'_id': ['Delphine Coulin', 'Muriel Coulin'], 'avg_rating': 6.0}
# {'_id': ['Morgan Freeman'], 'avg_rating': 6.5}
# {'_id': ['Marlon Riggs'], 'avg_rating': 7.2}
# {'_id': ['Juana Macèas'], 'avg_rating': 6.5}
# {'_id': ['Brian A Miller'], 'avg_rating': 4.5}
# {'_id': ['Pantelis Voulgaris'], 'avg_rating': 7.65}
# {'_id': ['Mitsuo Yanagimachi'], 'avg_rating': 7.0}
# {'_id': ['Robert Greenwald'], 'avg_rating': 6.575}
# {'_id': ['Nina Conti'], 'avg_rating': 7.5}
# {'_id': ['Pjer Zalica'], 'avg_rating': 7.4}
# {'_id': ['Louise Osmond', 'Jerry Rothwell'], 'avg_rating': 7.9}
# {'_id': ['Kenneth A. Carlson'], 'avg_rating': 7.4}
# {'_id': ['Jan Ole Gerster'], 'avg_rating': 7.4}
# {'_id': ['Sylvie Michel'], 'avg_rating': 6.1}
# {'_id': ['Morgan Matthews'], 'avg_rating': 7.2}
# {'_id': ['Aurora Guerrero'], 'avg_rating': 5.9}
# {'_id': ['Ali Akbarzadeh'], 'avg_rating': 8.8}
# {'_id': ['Will Slocombe'], 'avg_rating': 5.8}
# {'_id': ['Georgiy Daneliya', 'Tatiana Ilyina'], 'avg_rating': 6.0}
# {'_id': ['Edward Dmytryk'], 'avg_rating': 7.1461538461538465}
# {'_id': ['Malcolm Clarke', 'Stuart Sender'], 'avg_rating': 7.6}
# {'_id': ['Geoff Marslett'], 'avg_rating': 5.300000000000001}
# {'_id': ['Paul F. Ryan'], 'avg_rating': 7.3}
# {'_id': ['Marcel Ophèls'], 'avg_rating': 8.166666666666666}
# {'_id': ['Ulrike Koch'], 'avg_rating': 7.4}
# {'_id': ['Sean Garrity'], 'avg_rating': 6.449999999999999}
# {'_id': ['Adam Foulkes', 'Alan Smith'], 'avg_rating': 7.0}
# {'_id': ['Terry Jones', 'Terry Gilliam'], 'avg_rating': 7.6}
# {'_id': ['Steve Barnett'], 'avg_rating': 5.2}
# {'_id': ['Alexandre de La Patellière', 'Matthieu Delaporte'], 'avg_rating': 7.3}
# {'_id': ['Matthias Schweighèfer', 'Torsten Kènstler'], 'avg_rating': 5.6}
# {'_id': ['Rodman Flender'], 'avg_rating': 6.6}
# {'_id': ['Neal Israel'], 'avg_rating': 4.15}
# {'_id': ['Alejo Flah'], 'avg_rating': 5.9}
# {'_id': ['Richard Ayoade'], 'avg_rating': 6.9}
# {'_id': ['Jackie Oudney'], 'avg_rating': 6.5}
# {'_id': ['Elizabeth Gill'], 'avg_rating': 6.4}
# {'_id': ['Ana Katz'], 'avg_rating': 5.5}
# {'_id': ['John Pilger', 'Sean Crotty'], 'avg_rating': 8.4}
# {'_id': ['Ang Lee'], 'avg_rating': 7.3307692307692305}
# {'_id': ['Zeki Demirkubuz'], 'avg_rating': 7.6}
# {'_id': ['Srdjan Karanovic'], 'avg_rating': 7.2}
# {'_id': ['Stacie Passon'], 'avg_rating': 5.7}
# {'_id': ['Todd Phillips'], 'avg_rating': 6.644444444444444}
# {'_id': ['Laurie Collyer'], 'avg_rating': 6.15}
# {'_id': ['Maria Joèo Ganga'], 'avg_rating': 7.2}
# {'_id': ['Gil-young Jung'], 'avg_rating': 6.4}
# {'_id': ['Lauren Greenfield'], 'avg_rating': 7.1}
# {'_id': ['Brian Koppelman', 'David Levien'], 'avg_rating': 6.4}
# {'_id': ['Paul Gordon'], 'avg_rating': 6.2}
# {'_id': ['Nelson George'], 'avg_rating': 6.9}
# {'_id': ['Nzingha Stewart'], 'avg_rating': 5.7}
# {'_id': ['Sean Bardin', 'Robert Cooley'], 'avg_rating': 4.6}
# {'_id': ['Matthew Wolfe'], 'avg_rating': 8.7}
# {'_id': ['Shahriar Bahrani'], 'avg_rating': 6.8}
# {'_id': ['Dean Parisot'], 'avg_rating': 6.7}
# {'_id': ['Anne K. Black'], 'avg_rating': 4.9}
# {'_id': ['Christopher Radcliff', 'Lauren Wolkstein'], 'avg_rating': 6.7}
# {'_id': ['Harry Cleven'], 'avg_rating': 5.7}
# {'_id': ['John D. Hancock'], 'avg_rating': 6.3999999999999995}
# {'_id': ['Neill Blomkamp'], 'avg_rating': 7.35}
# {'_id': ['Jim McBride'], 'avg_rating': 6.566666666666666}
# {'_id': ['Chris Waitt'], 'avg_rating': 6.3}
# {'_id': ['Lisa Leeman'], 'avg_rating': 6.5}
# {'_id': ['John Magary'], 'avg_rating': 6.5}
# {'_id': ['David Hickson'], 'avg_rating': 7.2}
# {'_id': ['Hark Tsui'], 'avg_rating': 6.588888888888889}
# {'_id': ['Matthew Kohnen'], 'avg_rating': 5.7}
# {'_id': ['Paul Cox'], 'avg_rating': 6.833333333333333}
# {'_id': ['Mark Rucker'], 'avg_rating': 6.5}
# {'_id': ['David Bond', 'Melinda McDougall'], 'avg_rating': 6.1}
# {'_id': ['Lars Kraume'], 'avg_rating': 6.4}
# {'_id': ['Carlos Marques-Marcet'], 'avg_rating': 6.8}
# {'_id': ['Mary Stuart Masterson'], 'avg_rating': 6.5}
# {'_id': ['Stephen Chbosky'], 'avg_rating': 8.0}
# {'_id': ['Nagesh Kukunoor'], 'avg_rating': 6.933333333333334}
# {'_id': ['Jayson Thiessen', 'Ishi Rudell'], 'avg_rating': 7.4}
# {'_id': ['Marshall Lewy'], 'avg_rating': 6.1}
# {'_id': ['Luc Vinciguerra'], 'avg_rating': 6.3}
# {'_id': ['Andrè Heller', 'Othmar Schmiderer'], 'avg_rating': 7.3}
# {'_id': ['Toshio Lee'], 'avg_rating': 6.9}
# {'_id': ['Suresh Krishna'], 'avg_rating': 7.75}
# {'_id': ['Tim Sullivan'], 'avg_rating': 5.4}
# {'_id': ['Alberto Mar'], 'avg_rating': 4.8}
# {'_id': ['Hattie Dalton'], 'avg_rating': 7.7}
# {'_id': ['Breno Silveira'], 'avg_rating': 7.0}
# {'_id': ['Andy Goddard'], 'avg_rating': 5.8}
# {'_id': ['Mikko Niskanen'], 'avg_rating': 6.68}
# {'_id': ['F. Gary Gray'], 'avg_rating': 6.785714285714286}
# {'_id': ['Marc Silver'], 'avg_rating': 7.3}
# {'_id': ['Tarsem Singh'], 'avg_rating': 6.475}
# {'_id': ['John Glen'], 'avg_rating': 6.233333333333333}
# {'_id': ['Jean-Franèois Laguionie'], 'avg_rating': 6.35}
# {'_id': ['Dan Aykroyd'], 'avg_rating': 4.8}
# {'_id': ['Tom Savini'], 'avg_rating': 6.9}
# {'_id': ['Tracey Moffatt'], 'avg_rating': 5.3}
# {'_id': ['Igor Kovalyov'], 'avg_rating': 7.3}
# {'_id': ['Griffin Dunne'], 'avg_rating': 6.1}
# {'_id': ['Sue Heel'], 'avg_rating': 5.1}
# {'_id': ['Geoffrey Sax'], 'avg_rating': 6.016666666666667}
# {'_id': ['Patryk Vega'], 'avg_rating': 7.2}
# {'_id': ['Rod Amateau'], 'avg_rating': 2.7}
# {'_id': ['Tetsuo Shinohara'], 'avg_rating': 7.3}
# {'_id': ['Jessica Hausner'], 'avg_rating': 6.166666666666667}
# {'_id': ['Allison Anders'], 'avg_rating': 6.540000000000001}
# {'_id': ['Michael Polish'], 'avg_rating': 6.371428571428572}
# {'_id': ['Robert Ben Garant'], 'avg_rating': 5.9}
# {'_id': ['Nanette Burstein', 'Brett Morgen'], 'avg_rating': 7.35}
# {'_id': ['Lamont Johnson'], 'avg_rating': 6.642857142857143}
# {'_id': ['Daniel Lapaine'], 'avg_rating': 6.0}
# {'_id': ['Charles Haid'], 'avg_rating': 6.4}
# {'_id': ['Juan Carlos Fresnadillo'], 'avg_rating': 6.433333333333334}
# {'_id': ['Michael Kalesniko'], 'avg_rating': 7.0}
# {'_id': ['Laurent Cantet'], 'avg_rating': 6.8500000000000005}
# {'_id': ['Jacques-Rèmy Girerd'], 'avg_rating': 6.6}
# {'_id': ['Raya Martin'], 'avg_rating': 6.4}
# {'_id': ['Khaled Marei'], 'avg_rating': 8.1}
# {'_id': ['Hugh Sullivan'], 'avg_rating': 6.4}
# {'_id': ['Edwin'], 'avg_rating': 6.0}
# {'_id': ['Sidney Poitier'], 'avg_rating': 5.966666666666666}
# {'_id': ['Dudley Nichols'], 'avg_rating': 6.8}
# {'_id': ['Paul Bartel'], 'avg_rating': 6.5}
# {'_id': ['Jennifer Wynne Farmer', 'Valerie Red-Horse'], 'avg_rating': 6.4}
# {'_id': ['Rakeysh Omprakash Mehra'], 'avg_rating': 7.44}
# {'_id': ['Sunu Gonera'], 'avg_rating': 5.7}
# {'_id': ['Julia Loktev'], 'avg_rating': 5.85}
# {'_id': ['Margaret Brown'], 'avg_rating': 6.75}
# {'_id': ['Arjun Sablok'], 'avg_rating': 5.1}
# {'_id': ['Rèmi Lange'], 'avg_rating': 7.0}
# {'_id': ['Margot Benacerraf'], 'avg_rating': 7.8}
# {'_id': ['Steven Schachter'], 'avg_rating': 6.9}
# {'_id': ['Justin Edgar'], 'avg_rating': 4.300000000000001}
# {'_id': ['Henry Cornelius'], 'avg_rating': 7.25}
# {'_id': ['Vicco von Bèlow', 'Renate Westphal-Lorenz'], 'avg_rating': 8.1}
# {'_id': ['Peter Handke'], 'avg_rating': 6.55}
# {'_id': ['Ha Yoo'], 'avg_rating': 7.140000000000001}
# {'_id': ['Craig M. Saavedra'], 'avg_rating': 5.5}
# {'_id': ['Mona Achache'], 'avg_rating': 7.4}
# {'_id': ['Rebecca Richman Cohen'], 'avg_rating': 7.3}
# {'_id': ['Manny Coto'], 'avg_rating': 5.733333333333333}
# {'_id': ['Jim Brown'], 'avg_rating': 8.3}
# {'_id': ['Henri Verneuil'], 'avg_rating': 7.4799999999999995}
# {'_id': ['Jay Chandrasekhar'], 'avg_rating': 5.8}
# {'_id': ['Gooc-jin Ahn'], 'avg_rating': None}
# {'_id': ['Carlo Verdone'], 'avg_rating': 6.310526315789474}
# {'_id': ['Stian Kristiansen'], 'avg_rating': 7.1}
# {'_id': ['John Lafia'], 'avg_rating': 4.875}
# {'_id': ['Paul Middleditch'], 'avg_rating': 5.7}
# {'_id': ['Richard Press'], 'avg_rating': 7.9}
# {'_id': ['Dominic Anciano', 'Ray Burdis'], 'avg_rating': 6.1}
# {'_id': ['Jacques Tourneur'], 'avg_rating': 7.32}
# {'_id': ['Curt Geda'], 'avg_rating': 7.9}
# {'_id': ['Philippe Claudel'], 'avg_rating': 7.6}
# {'_id': ['Jeff Preiss'], 'avg_rating': 6.3}
# {'_id': ['Wil Shriner'], 'avg_rating': 5.6}
# {'_id': ['James Whale'], 'avg_rating': 7.825}
# {'_id': ['Phil Traill'], 'avg_rating': 4.8}
# {'_id': ['Michael Lantieri'], 'avg_rating': 4.0}
# {'_id': ['Nishikant Kamat'], 'avg_rating': 6.949999999999999}
# {'_id': ['Anna Reeves'], 'avg_rating': 6.7}
# {'_id': ['Keith Melton'], 'avg_rating': 6.5}
# {'_id': ['Hun Jang'], 'avg_rating': 7.35}
# {'_id': ['Simon Curtis'], 'avg_rating': 7.0}
# {'_id': ['Kai Wessel'], 'avg_rating': 6.7}
# {'_id': ['Paul McEvoy'], 'avg_rating': 6.9}
# {'_id': ['Stuart Urban'], 'avg_rating': 5.900000000000001}
# {'_id': ['Daisy von Scherler Mayer'], 'avg_rating': 5.625}
# {'_id': ['Enrique Urbizu'], 'avg_rating': 6.4}
# {'_id': ['Gregory Doran'], 'avg_rating': 8.2}
# {'_id': ['Yèichi Satè'], 'avg_rating': 7.4}
# {'_id': ['Robert Taylor'], 'avg_rating': 5.4}
# {'_id': ['Yolanda Garcèa Serrano', 'Juan Luis Iborra'], 'avg_rating': 7.2}
# {'_id': ['Murray Fahey'], 'avg_rating': 6.1}
# {'_id': ['Tae-yong Kim', 'Kyu-dong Min'], 'avg_rating': 6.7}
# {'_id': ['Uri Barbash'], 'avg_rating': 6.8}
# {'_id': ['Doris Dèrrie'], 'avg_rating': 6.785714285714286}
# {'_id': ['Darrell Rooney', 'Jeannine Roussel'], 'avg_rating': 5.9}
# {'_id': ['Jasmila Zbanic'], 'avg_rating': 7.3}
# {'_id': ['Eric Civanyan'], 'avg_rating': 5.6}
# {'_id': ['Marcos Siega'], 'avg_rating': 6.6}
# {'_id': ['Jeffrey Lau'], 'avg_rating': 7.1}
# {'_id': ['Scooter McCrae'], 'avg_rating': 3.8}
# {'_id': ['Terence Fisher'], 'avg_rating': 7.033333333333334}
# {'_id': ['Michael Goguen', 'Seung Eun Kim', 'Sam Liu', 'Brandon Vietti'], 'avg_rating': 6.7}
# {'_id': ['Orson Welles', 'Fred Fleck', 'Robert Wise'], 'avg_rating': 7.9}
# {'_id': ['Aprill Winney'], 'avg_rating': 8.1}
# {'_id': ['John Krokidas'], 'avg_rating': 6.5}
# {'_id': ['Andrea Segre'], 'avg_rating': 7.3}
# {'_id': ['Andrew Piddington'], 'avg_rating': 6.3}
# {'_id': ['Matthias Luthardt'], 'avg_rating': 6.8}
# {'_id': ['Carl Theodor Dreyer'], 'avg_rating': 8.0}
# {'_id': ['Emily Atef'], 'avg_rating': 6.9}
# {'_id': ['Charles Evered'], 'avg_rating': 5.2}
# {'_id': ['Hans Dahlberg'], 'avg_rating': 6.6}
# {'_id': ['Miroslav Slaboshpitsky'], 'avg_rating': 7.4}
# {'_id': ['Jeff Pollack'], 'avg_rating': 6.6}
# {'_id': ['Oren Kaplan'], 'avg_rating': 7.2}
# {'_id': ['Jim Henson'], 'avg_rating': 7.633333333333334}
# {'_id': ['Mark Neveldine', 'Brian Taylor'], 'avg_rating': 5.825}
# {'_id': ['Charlotte Purdy'], 'avg_rating': 7.4}
# {'_id': ['Stèphane Aubier', 'Vincent Patar', 'Benjamin Renner'], 'avg_rating': 7.9}
# {'_id': ['King Vidor'], 'avg_rating': 7.188888888888889}
# {'_id': ['Imtiaz Ali'], 'avg_rating': 7.733333333333333}
# {'_id': ['Adrian Popovici'], 'avg_rating': 5.5}
# {'_id': ['Dominic Savage'], 'avg_rating': 6.9}
# {'_id': ['Joèo Jardim'], 'avg_rating': 7.066666666666666}
# {'_id': ['Tamara Hernandez'], 'avg_rating': 5.6}
# {'_id': ['Masahiko Nagasawa'], 'avg_rating': 6.4}
# {'_id': ['Robert Young'], 'avg_rating': 6.35}
# {'_id': ['Kenneth Bi'], 'avg_rating': 7.1}
# {'_id': ['Lisa Azuelos'], 'avg_rating': 5.6000000000000005}
# {'_id': ['Kuo-fu Chen', 'Qunshu Gao'], 'avg_rating': 7.4}
# {'_id': ['Antonio Hens'], 'avg_rating': 5.6}
# {'_id': ['Pablo Croce'], 'avg_rating': 7.0}
# {'_id': ['Robert Wise'], 'avg_rating': 7.1}
# {'_id': ['Matt Cimber'], 'avg_rating': 4.5}
# {'_id': ['Dome Karukoski'], 'avg_rating': 6.833333333333333}
# {'_id': ['Michael Tolkin'], 'avg_rating': 6.050000000000001}
# {'_id': ['David Nerlich', 'Andrew Traucki'], 'avg_rating': 6.0}
# {'_id': ['Brant Sersen'], 'avg_rating': 5.766666666666667}
# {'_id': ['Andrew Thomas Hunt'], 'avg_rating': 5.2}
# {'_id': ['Hal Salwen'], 'avg_rating': 6.9}
# {'_id': ['Scott Heming', 'Cathy Malkasian', 'Jeff McGrath'], 'avg_rating': 6.2}
# {'_id': ['Bruce Myles', 'Michael Pattinson'], 'avg_rating': 6.5}
# {'_id': ['Hèctor Olivera'], 'avg_rating': 6.2}
# {'_id': ['Liz Garbus'], 'avg_rating': 7.35}
# {'_id': ['Jeremy Joe Kronsberg'], 'avg_rating': 3.6}
# {'_id': ['Nancy Kelly'], 'avg_rating': 7.2}
# {'_id': ['Edward Sedgwick', 'Buster Keaton'], 'avg_rating': 8.3}
# {'_id': ['April Mullen'], 'avg_rating': 4.9}
# {'_id': ['Ali Hatami'], 'avg_rating': 7.7}
# {'_id': ['Lok Man Leung', 'Kim-Ching Luk'], 'avg_rating': 6.7}
# {'_id': ['Laurel Chiten'], 'avg_rating': 5.9}
# {'_id': ['Gaspar Noè'], 'avg_rating': 7.18}
# {'_id': ['Gary Sherman'], 'avg_rating': 5.75}
# {'_id': ['Ross Kagan Marks'], 'avg_rating': 6.3}
# {'_id': ['Bill Corcoran'], 'avg_rating': 5.5}
# {'_id': ['Ken Annakin', 'Harold French'], 'avg_rating': 7.3}
# {'_id': ['Akira Inoue'], 'avg_rating': 7.6}
# {'_id': ['Kristian Levring'], 'avg_rating': 6.5}
# {'_id': ['Phillip Noyce'], 'avg_rating': 6.664285714285714}
# {'_id': ['Rudolph Matè'], 'avg_rating': 7.066666666666666}
# {'_id': ['Lance Mungia'], 'avg_rating': 4.85}
# {'_id': ['Michael Anderson'], 'avg_rating': 6.409999999999999}
# {'_id': ['Xavier Beauvois'], 'avg_rating': 7.050000000000001}
# {'_id': ['Marèa Novaro'], 'avg_rating': 7.1}
# {'_id': ['Kirill Kuzin'], 'avg_rating': 3.0}
# {'_id': ['Henry Winkler'], 'avg_rating': 3.8}
# {'_id': ['Ry Russo-Young'], 'avg_rating': 5.050000000000001}
# {'_id': ['Josh Gordon', 'Will Speck'], 'avg_rating': 6.199999999999999}
# {'_id': ['Toniko Melo'], 'avg_rating': 6.6}
# {'_id': ['Nanouk Leopold'], 'avg_rating': 6.2}
# {'_id': ['Josh Appignanesi'], 'avg_rating': 6.4}
# {'_id': ['Bui Thac Chuyèn'], 'avg_rating': 6.6}
# {'_id': ['Dejan Zecevic'], 'avg_rating': 7.3}
# {'_id': ['Mike Dacko'], 'avg_rating': 7.5}
# {'_id': ['Vèclav Vorlècek'], 'avg_rating': 7.3}
# {'_id': ['Nicole Conn'], 'avg_rating': 6.1}
# {'_id': ['Coley Sohn'], 'avg_rating': 6.2}
# {'_id': ['Sang Man Kim'], 'avg_rating': 6.7}
# {'_id': ['David Roach', 'Warwick Ross'], 'avg_rating': 6.7}
# {'_id': ['Charles Crichton', 'John Cleese'], 'avg_rating': 7.6}
# {'_id': ['Jeff Daniels'], 'avg_rating': 4.5}
# {'_id': ['Mark Benjamin', 'Danny Hoch'], 'avg_rating': 7.8}
# {'_id': ['Selton Mello'], 'avg_rating': 7.4}
# {'_id': ['Brett Ratner'], 'avg_rating': 6.51}
# {'_id': ['Fred M. Wilcox'], 'avg_rating': 7.45}
# {'_id': ['Michael James Rowland'], 'avg_rating': 7.1}
# {'_id': ['Anthony Gaudioso', 'James Gaudioso'], 'avg_rating': None}
# {'_id': ['Bob Logan'], 'avg_rating': 4.7}
# {'_id': ['Daniel Wolfe'], 'avg_rating': 6.7}
# {'_id': ['Krzysztof Lang'], 'avg_rating': 6.3}
# {'_id': ['Bartek Kulas'], 'avg_rating': 7.0}
# {'_id': ['Steven Knight'], 'avg_rating': 7.1}
# {'_id': ['Ronit Elkabetz', 'Shlomi Elkabetz'], 'avg_rating': 7.8}
# {'_id': ['Chris LaMartina', 'James Branscome', 'Shawn Jones', 'Scott Maccubbin', 'Lonnie Martin', 'Matthew Menter', 'Andy Schoeb'], 'avg_rating': 6.8}
# {'_id': ['Jesse Moss'], 'avg_rating': 7.5}
# {'_id': ['Jung-hoon Kim'], 'avg_rating': 6.7}
# {'_id': ['Paul Haggis'], 'avg_rating': 7.0600000000000005}
# {'_id': ['Yasujirè Ozu'], 'avg_rating': 8.0}
# {'_id': ["Matthew O'Callaghan"], 'avg_rating': 6.6}
# {'_id': ["Jun'ichi Satè", 'Rob Bakewell'], 'avg_rating': 6.9}
# {'_id': ['Jeremy Haft'], 'avg_rating': 5.2}
# {'_id': ['Rachel Samuels'], 'avg_rating': 4.6}
# {'_id': ['Hartmut Bitomsky'], 'avg_rating': 6.3}
# {'_id': ['Toshiyuki Kubooka'], 'avg_rating': 7.7}
# {'_id': ['Aarèn Fernèndez Lesur'], 'avg_rating': 6.55}
# {'_id': ['Samuel Fuller'], 'avg_rating': 7.133333333333333}
# {'_id': ['Fausto Brizzi'], 'avg_rating': 5.779999999999999}
# {'_id': ['Robert Z. Leonard', 'W.S. Van Dyke'], 'avg_rating': 7.0}
# {'_id': ['Barney Elliott'], 'avg_rating': 7.6}
# {'_id': ['Connie Field'], 'avg_rating': 7.0}
# {'_id': ['Natsuki Imai'], 'avg_rating': 7.1}
# {'_id': ['Todd Williams'], 'avg_rating': 6.3}
# {'_id': ['Peter Lindholm'], 'avg_rating': 5.633333333333333}
# {'_id': ['Greg Harrison'], 'avg_rating': 6.05}
# {'_id': ['Tom Gilroy'], 'avg_rating': 7.4}
# {'_id': ['Hal Ashby'], 'avg_rating': 6.779999999999999}
# {'_id': ['Rania Attieh', 'Daniel Garcia'], 'avg_rating': 6.3}
# {'_id': ['Scott Derrickson'], 'avg_rating': 6.16}
# {'_id': ['Vadim Jean'], 'avg_rating': 5.5}
# {'_id': ['Martin Villeneuve'], 'avg_rating': 5.9}
# {'_id': ['James Clavell'], 'avg_rating': 7.7}
# {'_id': ['Sam Irvin'], 'avg_rating': 5.2}
# {'_id': ['Alan Wade'], 'avg_rating': 6.1}
# {'_id': ['Gary Nelson'], 'avg_rating': 5.933333333333334}
# {'_id': ['Doron Eran'], 'avg_rating': 5.5}
# {'_id': ['Rashaad Ernesto Green'], 'avg_rating': 6.6}
# {'_id': ['Randall Wallace'], 'avg_rating': 6.625}
# {'_id': ['Frederick De Cordova'], 'avg_rating': 5.6}
# {'_id': ['Clay Liford'], 'avg_rating': 4.2}
# {'_id': ['Per-Olav Sèrensen'], 'avg_rating': 5.5}
# {'_id': ['Rob LaDuca'], 'avg_rating': 7.2}
# {'_id': ['Mike Mills'], 'avg_rating': 6.95}
# {'_id': ['Kyle Patrick Alvarez'], 'avg_rating': 6.366666666666667}
# {'_id': ['John McKay'], 'avg_rating': 6.3}
# {'_id': ['Carol Morley'], 'avg_rating': 6.25}
# {'_id': ['Otto Preminger', 'Rouben Mamoulian'], 'avg_rating': 7.5}
# {'_id': ['Sèlveig Anspach'], 'avg_rating': 6.466666666666666}
# {'_id': ['John Lounsbery'], 'avg_rating': 7.8}
# {'_id': ['Barry Levinson'], 'avg_rating': 6.678947368421052}
# {'_id': ['Antonio Banderas'], 'avg_rating': 6.3}
# {'_id': ['Johnny E. Jensen'], 'avg_rating': 7.5}
# {'_id': ['Vladan Nikolic'], 'avg_rating': 6.0}
# {'_id': ['Hèlène Cattet', 'Bruno Forzani'], 'avg_rating': 6.15}
# {'_id': ["Greg 'Freddy' Camalier"], 'avg_rating': 7.7}
# {'_id': ['Diane Keaton'], 'avg_rating': 5.7}
# {'_id': ['Fernando Grostein Andrade', 'Cosmo Feilding-Mellen'], 'avg_rating': 7.7}
# {'_id': ['Jirè Barta'], 'avg_rating': 8.0}
# {'_id': ['Philippe Falardeau'], 'avg_rating': 7.32}
# {'_id': ['Michael Paxton'], 'avg_rating': 6.9}
# {'_id': ['Hella Joof'], 'avg_rating': 6.0}
# {'_id': ['Gèza von Radvènyi'], 'avg_rating': 7.1}
# {'_id': ['Andrew Knight'], 'avg_rating': 6.1}
# {'_id': ['Mike Slee'], 'avg_rating': 6.8}
# {'_id': ['John Fawcett'], 'avg_rating': 6.4}
# {'_id': ['Matthew Bright'], 'avg_rating': 6.233333333333334}
# {'_id': ['Christian Chaudet'], 'avg_rating': 7.4}
# {'_id': ['Matthew Cooke'], 'avg_rating': 7.7}
# {'_id': ['David Carson'], 'avg_rating': 6.05}
# {'_id': ['Michael Webber'], 'avg_rating': 7.3}
# {'_id': ['Lieven Debrauwer'], 'avg_rating': 7.0}
# {'_id': ['Byeong-gil Jeong'], 'avg_rating': 7.0}
# {'_id': ['Jake Gavin'], 'avg_rating': 7.8}
# {'_id': ['Markus Schleinzer'], 'avg_rating': 7.0}
# {'_id': ['Damon Russell'], 'avg_rating': 6.6}
# {'_id': ['Steven Silver'], 'avg_rating': 7.0}
# {'_id': ['èmèr Atay', 'Selim Demirdelen', 'Kudret Sabanci', 'Yècel Yolcu', 'èmit ènal'], 'avg_rating': 7.4}
# {'_id': ['Frank Capra', 'Hugh Stewart', 'John Huston'], 'avg_rating': 6.9}
# {'_id': ['Randy Redroad'], 'avg_rating': 7.0}
# {'_id': ['Richard Elfman'], 'avg_rating': 5.65}
# {'_id': ['Michel Gondry'], 'avg_rating': 6.76}
# {'_id': ['Aleksandr Zeldovich'], 'avg_rating': 6.15}
# {'_id': ['Arturo Ripstein'], 'avg_rating': 7.271428571428571}
# {'_id': ['Yukihiko Tsutsumi'], 'avg_rating': 6.659999999999999}
# {'_id': ['Lucky McKee', 'Chris Sivertson'], 'avg_rating': 5.2}
# {'_id': ['Gaston Biraben'], 'avg_rating': 7.5}
# {'_id': ['Marcel Rasquin'], 'avg_rating': 7.5}
# {'_id': ['Mark Edwin Robinson'], 'avg_rating': 4.5}
# {'_id': ['Daniel Young'], 'avg_rating': 5.1}
# {'_id': ['Niki Caro'], 'avg_rating': 7.5}
# {'_id': ['Iulia Rugina'], 'avg_rating': 7.1}
# {'_id': ['Mikkel Brènne Sandemose'], 'avg_rating': 5.9}
# {'_id': ['Tim Roth'], 'avg_rating': 7.4}
# {'_id': ['Melissa Painter'], 'avg_rating': 5.6}
# {'_id': ['Aaron Schock'], 'avg_rating': 7.1}
# {'_id': ['Randy Moore'], 'avg_rating': 5.2}
# {'_id': ['John Ford', 'Emilio Fernèndez'], 'avg_rating': 6.6}
# {'_id': ['Neil LaBute'], 'avg_rating': 6.1}
# {'_id': ['Nonzee Nimibutr'], 'avg_rating': 6.2}
# {'_id': ['Thorbjèrn Christoffersen', 'Craig Frank'], 'avg_rating': 5.7}
# {'_id': ['Matt Wolf'], 'avg_rating': 6.7}
# {'_id': ['Tom Brady'], 'avg_rating': 4.266666666666667}
# {'_id': ['Jèrgen Leth'], 'avg_rating': 4.4}
# {'_id': ['Ethan Wiley'], 'avg_rating': 5.3}
# {'_id': ['Dustin Hoffman'], 'avg_rating': 6.8}
# {'_id': ['David Jackson', 'Dick Lowry'], 'avg_rating': 4.6}
# {'_id': ['Mehdi Karampoor'], 'avg_rating': 5.7}
# {'_id': ['Nattawut Poonpiriya'], 'avg_rating': 6.4}
# {'_id': ['Edward Norton'], 'avg_rating': 6.4}
# {'_id': ['Pedro Costa'], 'avg_rating': 7.12}
# {'_id': ['Joe Ahearne'], 'avg_rating': 7.8}
# {'_id': ['Thornton Freeland'], 'avg_rating': 6.7}
# {'_id': ['Rodrigo Moreno'], 'avg_rating': 6.6}
# {'_id': ['Olivier Coussemacq'], 'avg_rating': 6.1}
# {'_id': ['Jens èstberg'], 'avg_rating': 5.5}
# {'_id': ['Guto Parente'], 'avg_rating': 7.1}
# {'_id': ['Howard Hall'], 'avg_rating': 7.65}
# {'_id': ['Robert Enrico'], 'avg_rating': 7.7}
# {'_id': ['Amy Heckerling'], 'avg_rating': 5.916666666666667}
# {'_id': ['Yavuz Turgul'], 'avg_rating': 8.5}
# {'_id': ['Brent Young'], 'avg_rating': 6.5}
# {'_id': ['Kevin Reynolds'], 'avg_rating': 6.7}
# {'_id': ['Bruno Dumont'], 'avg_rating': 6.428571428571429}
# {'_id': ['Peter Shaner'], 'avg_rating': 4.8}
# {'_id': ['John Erman'], 'avg_rating': 6.466666666666666}
# {'_id': ['Gaylene Preston'], 'avg_rating': 7.9}
# {'_id': ['Anthony Chen'], 'avg_rating': 7.3}
# {'_id': ['Derek Jarman'], 'avg_rating': 6.833333333333333}
# {'_id': ['Tom Hooper'], 'avg_rating': 7.58}
# {'_id': ['Rocco Papaleo'], 'avg_rating': 6.45}
# {'_id': ['Aron Gaudet', 'Gita Pullapilly'], 'avg_rating': 6.2}
# {'_id': ['Siegfried'], 'avg_rating': 7.2}
# {'_id': ['Andrew Cymek'], 'avg_rating': 3.4}
# {'_id': ['James Toback'], 'avg_rating': 7.6}
# {'_id': ['Kirill Lavrov', 'Ivan Pyryev', 'Mikhail Ulyanov'], 'avg_rating': 7.6}
# {'_id': ['Bahram Tavakoli'], 'avg_rating': 8.1}
# {'_id': ['Anna Odell'], 'avg_rating': 7.0}
# {'_id': ['Julia Rezende'], 'avg_rating': 6.0}
# {'_id': ['Charles de Lauzirika'], 'avg_rating': 5.3}
# {'_id': ['William Asher'], 'avg_rating': 5.6000000000000005}
# {'_id': ['Angela Christlieb', 'Stephen Kijak'], 'avg_rating': 7.1}
# {'_id': ['Charles McDougall'], 'avg_rating': 6.7}
# {'_id': ['Ben Cookson'], 'avg_rating': 4.2}
# {'_id': ['Asger Leth', 'Milos Loncarevic'], 'avg_rating': 7.2}
# {'_id': ['Alonso Ruizpalacios'], 'avg_rating': 7.8}
# {'_id': ['Eliaichi Kimaro'], 'avg_rating': 8.2}
# {'_id': ['Norma Bailey'], 'avg_rating': 6.5}
# {'_id': ['D.W. Griffith'], 'avg_rating': 7.275}
# {'_id': ['Isaac Julien', 'Bernard Rose'], 'avg_rating': 7.1}
# {'_id': ['Sergio Citti'], 'avg_rating': 7.3}
# {'_id': ['Jon Alpert', 'Ellen Goosenberg Kent', "Matthew O'Neill"], 'avg_rating': 7.7}
# {'_id': ['Aleksandr Strizhenov'], 'avg_rating': 5.6}
# {'_id': ['Zach Cregger', 'Trevor Moore'], 'avg_rating': 5.1}
# {'_id': ['Azuma Morisaki'], 'avg_rating': 7.3}
# {'_id': ['David Gregory'], 'avg_rating': 7.6}
# {'_id': ['Lewis Milestone', 'Carol Reed'], 'avg_rating': 7.2}
# {'_id': ['Benedikt Erlingsson'], 'avg_rating': 6.9}
# {'_id': ['Jamie Mitchell', 'Charles Grosvenor'], 'avg_rating': 5.7}
# {'_id': ['Madonna'], 'avg_rating': 6.2}
# {'_id': ['Eric Valli', 'Michel Debats'], 'avg_rating': 7.5}
# {'_id': ['Xavier Villaverde'], 'avg_rating': 5.8}
# {'_id': ['Pèter Forgècs'], 'avg_rating': 6.95}
# {'_id': ['Felix Thompson'], 'avg_rating': 8.2}
# {'_id': ['Benjamin Heisenberg'], 'avg_rating': 6.8}
# {'_id': ['Eric Bricker'], 'avg_rating': 7.4}
# {'_id': ['Ryan White'], 'avg_rating': 7.3}
# {'_id': ['Yibai Zhang'], 'avg_rating': 7.0}
# {'_id': ['Sophie Letourneur'], 'avg_rating': 5.050000000000001}
# {'_id': ['Paul Crowder', 'Murray Lerner', 'Parris Patton'], 'avg_rating': 8.2}
# {'_id': ['Abhishek Chaubey'], 'avg_rating': 7.35}
# {'_id': ['Alexandra Kondracke'], 'avg_rating': 6.4}
# {'_id': ['Constantina Voulgaris'], 'avg_rating': 6.7}
# {'_id': ['Joe Mantegna'], 'avg_rating': 6.1}
# {'_id': ['Geneviève Mersch'], 'avg_rating': 6.1}
# {'_id': ['Patrick Sheane Duncan'], 'avg_rating': 7.0}
# {'_id': ['Maris Martinsons'], 'avg_rating': 6.6}
# {'_id': ['Su Friedrich'], 'avg_rating': 7.2}
# {'_id': ['Siddharth Anand'], 'avg_rating': 6.04}
# {'_id': ['Fernando Lopes'], 'avg_rating': 6.8}
# {'_id': ['Alex van Warmerdam'], 'avg_rating': 7.066666666666666}
# {'_id': ['Hugo Van Lawick'], 'avg_rating': 7.3}
# {'_id': ['Ali Abbas Zafar'], 'avg_rating': 3.8499999999999996}
# {'_id': ['Harmesh Malhotra'], 'avg_rating': 6.4}
# {'_id': ['Abel Gance'], 'avg_rating': 7.4}
# {'_id': ['Reed Morano'], 'avg_rating': 8.3}
# {'_id': ['John Cromwell', 'Edward F. Cline', 'Tay Garnett', 'David O. Selznick'], 'avg_rating': 7.7}
# {'_id': ['Patrik Syversen'], 'avg_rating': 5.1}
# {'_id': ['Alex Garland'], 'avg_rating': 7.7}
# {'_id': ['Josè Ferrer'], 'avg_rating': 6.55}
# {'_id': ['Gerardo Herrero'], 'avg_rating': 5.933333333333334}
# {'_id': ['Clyde Geronimi', 'Wilfred Jackson', 'Hamilton Luske'], 'avg_rating': 7.366666666666667}
# {'_id': ['Randall Rubin', 'Jon Schroder'], 'avg_rating': 6.2}
# {'_id': ['William A. Seiter'], 'avg_rating': 7.266666666666667}
# {'_id': ['James Longley'], 'avg_rating': 7.3}
# {'_id': ['Jiska Rickels'], 'avg_rating': 7.5}
# {'_id': ['Kambuzia Partovi'], 'avg_rating': 7.4}
# {'_id': ['Robert A. Masciantonio'], 'avg_rating': 4.0}
# {'_id': ['Andrew Kotting'], 'avg_rating': 5.7}
# {'_id': ['Brian Crano'], 'avg_rating': 6.7}
# {'_id': ['Courtney Ware'], 'avg_rating': None}
# {'_id': ['Dominique Monfery'], 'avg_rating': 7.9}
# {'_id': ['George Miller', 'Gary Eck', 'David Peers'], 'avg_rating': 5.9}
# {'_id': ['Michael Lembeck'], 'avg_rating': 5.183333333333334}
# {'_id': ['Bill Douglas'], 'avg_rating': 7.5}
# {'_id': ['Bruce Lee'], 'avg_rating': 7.3}
# {'_id': ['Todd Holland'], 'avg_rating': 5.7}
# {'_id': ['Miguel Sapochnik'], 'avg_rating': 6.3}
# {'_id': ['Michael Landon Jr.'], 'avg_rating': 6.859999999999999}
# {'_id': ['Gary Trousdale'], 'avg_rating': 6.5}
# {'_id': ['Alejandro Fernèndez Almendras'], 'avg_rating': 6.300000000000001}
# {'_id': ['Valeriya Gay Germanika'], 'avg_rating': 6.7}
# {'_id': ['Orson Welles'], 'avg_rating': 7.625}
# {'_id': ['Naoto Kumazawa'], 'avg_rating': 7.1}
# {'_id': ['Meera Menon'], 'avg_rating': 7.0}
# {'_id': ['Patrick Brice'], 'avg_rating': 6.300000000000001}
# {'_id': ['Damjan Kozole'], 'avg_rating': 6.3}
# {'_id': ['Jeff Chan'], 'avg_rating': 4.8}
# {'_id': ['Bruce Bundy', 'Nigel DeFriez', 'Jessie Levandov', 'Robert Malone', 'Alex Mechanik', 'Kira Pearson', 'Jonathan Rosenblit'], 'avg_rating': 7.1}
# {'_id': ['Jan Prusinovskè'], 'avg_rating': 7.9}
# {'_id': ['Ciro Guerra'], 'avg_rating': 7.85}
# {'_id': ['Luke Moran'], 'avg_rating': 5.3}
# {'_id': ['Frank Sebastiano'], 'avg_rating': 6.0}
# {'_id': ['Joe Berlinger'], 'avg_rating': 6.475}
# {'_id': ['Jeffrey Kusama-Hinte'], 'avg_rating': 7.0}
# {'_id': ['Goran Markovic'], 'avg_rating': 8.0}
# {'_id': ['Selim Evci'], 'avg_rating': 4.5}
# {'_id': ['Chandra Barot'], 'avg_rating': 7.9}
# {'_id': ['A. Karunakaran'], 'avg_rating': 7.3}
# {'_id': ['Gauri Shinde'], 'avg_rating': 7.9}
# {'_id': ['Kevin Derek'], 'avg_rating': 9.3}
# {'_id': ['Stèphanie Joalland'], 'avg_rating': 6.6}
# {'_id': ['Jerry LaMothe'], 'avg_rating': 6.1}
# {'_id': ['Anna Maria Tatè'], 'avg_rating': 7.8}
# {'_id': ['David Keith'], 'avg_rating': 4.9}
# {'_id': ['Evan Richards'], 'avg_rating': 7.0}
# {'_id': ['Adam Del Deo', 'James D. Stern'], 'avg_rating': 7.4}
# {'_id': ['J.A. Bayona'], 'avg_rating': 7.55}
# {'_id': ['Anca Damian'], 'avg_rating': 7.449999999999999}
# {'_id': ['Douglas Trumbull'], 'avg_rating': 6.6}
# {'_id': ['Ted Tetzlaff'], 'avg_rating': 7.5}
# {'_id': ['Camilo Cavalcante'], 'avg_rating': 8.0}
# {'_id': ['Michael Schorr'], 'avg_rating': 7.0}
# {'_id': ['Marc Fienberg'], 'avg_rating': 6.6}
# {'_id': ['John McTiernan', 'Michael Crichton'], 'avg_rating': 6.6}
# {'_id': ['Ethan Maniquis', 'Robert Rodriguez'], 'avg_rating': 6.7}
# {'_id': ['Sanping Han', 'Jianxin Huang'], 'avg_rating': 3.75}
# {'_id': ['Fred Walton'], 'avg_rating': 6.5}
# {'_id': ['Jem Cohen'], 'avg_rating': 6.9}
# {'_id': ['Herbert Blachè', 'Winchell Smith'], 'avg_rating': 6.2}
# {'_id': ['Denzel Washington'], 'avg_rating': 7.449999999999999}
# {'_id': ['Valeria Golino'], 'avg_rating': 6.7}
# {'_id': ['Ben Rock'], 'avg_rating': 5.6}
# {'_id': ['Kidlat Tahimik'], 'avg_rating': 7.3}
# {'_id': ['Robert Stone'], 'avg_rating': 7.15}
# {'_id': ['Steven R. Monroe'], 'avg_rating': 6.3}
# {'_id': ['Clarence Yiu-leung Fok'], 'avg_rating': 5.8}
# {'_id': ['William Dieterle'], 'avg_rating': 7.575}
# {'_id': ['Chih-yen Yee'], 'avg_rating': 7.5}
# {'_id': ['Oscar Micheaux'], 'avg_rating': 6.3}
# {'_id': ['Gabriele Salvatores'], 'avg_rating': 6.6571428571428575}
# {'_id': ['Justin Kerrigan'], 'avg_rating': 7.0}
# {'_id': ['Luca Lucini'], 'avg_rating': 6.6}
# {'_id': ['Tony Cookson'], 'avg_rating': 4.4}
# {'_id': ['Lèa Pool'], 'avg_rating': 6.925}
# {'_id': ['Greg Olliver'], 'avg_rating': 5.4}
# {'_id': ['Joji Matsuoka'], 'avg_rating': 7.1}
# {'_id': ['Bernard Salzmann'], 'avg_rating': 5.7}
# {'_id': ['Sook-Yin Lee'], 'avg_rating': 5.8}
# {'_id': ['Andrey Kudinenko'], 'avg_rating': 6.4}
# {'_id': ['Zach Niles', 'Banker White'], 'avg_rating': 8.3}
# {'_id': ['Lucy Bailey', 'Andrew Thompson'], 'avg_rating': 7.8}
# {'_id': ['John Blanchard'], 'avg_rating': 7.6}
# {'_id': ['Benjamèn èvila'], 'avg_rating': 7.1}
# {'_id': ['Guillaume Ivernel', 'Arthur Qwak'], 'avg_rating': 6.6}
# {'_id': ['Gian Alfonso Pacinotti'], 'avg_rating': 6.0}
# {'_id': ['Stephanie Soechtig'], 'avg_rating': 7.7}
# {'_id': ['Jeremy Berg'], 'avg_rating': 2.9}
# {'_id': ['Reem Kherici'], 'avg_rating': 5.6}
# {'_id': ['Richard Martin'], 'avg_rating': 4.4}
# {'_id': ['Claudio Fèh'], 'avg_rating': 4.4}
# {'_id': ['Rand Ravich'], 'avg_rating': 5.3}
# {'_id': ['Valeri Fokin'], 'avg_rating': 7.0}
# {'_id': ['Gustavo Mosquera R.'], 'avg_rating': 6.9}
# {'_id': ['Lothar Mendes', 'Alexander Korda'], 'avg_rating': 7.1}
# {'_id': ['Richard Kelly'], 'avg_rating': 6.3999999999999995}
# {'_id': ['Michael Haneke'], 'avg_rating': 7.328571428571428}
# {'_id': ['Mike Robe'], 'avg_rating': 6.4}
# {'_id': ['Jan Svankmajer'], 'avg_rating': 7.55}
# {'_id': ['Edward Buzzell'], 'avg_rating': 6.4}
# {'_id': ['Newt Arnold'], 'avg_rating': 6.8}
# {'_id': ['Christophe Gans'], 'avg_rating': 6.65}
# {'_id': ['Miguel Arteta'], 'avg_rating': 6.3500000000000005}
# {'_id': ['Jacques Perrin', 'Jacques Cluzaud'], 'avg_rating': 7.8}
# {'_id': ['Jack Cardiff'], 'avg_rating': 7.15}
# {'_id': ['John Slattery'], 'avg_rating': 6.1}
# {'_id': ['Jonathan Kahn'], 'avg_rating': 5.8}
# {'_id': ['Brett Morgen'], 'avg_rating': 7.5}
# {'_id': ['Gianni Di Gregorio'], 'avg_rating': 6.6}
# {'_id': ['Masayuki Suo'], 'avg_rating': 7.68}
# {'_id': ['Rod Lurie'], 'avg_rating': 6.7}
# {'_id': ['Joyce Bernal'], 'avg_rating': 6.6}
# {'_id': ['Isabelle Lavigne', 'Stèphane Thibault'], 'avg_rating': None}
# {'_id': ['Peter Sollett'], 'avg_rating': 6.9}
# {'_id': ['Dan Beers'], 'avg_rating': 5.9}
# {'_id': ['Claudia Lorenz'], 'avg_rating': 6.0}
# {'_id': ['Anucha Boonyawatana'], 'avg_rating': 7.3}
# {'_id': ['Jules Dassin'], 'avg_rating': 7.414285714285714}
# {'_id': ['Antony Thomas'], 'avg_rating': 7.3}
# {'_id': ['Olivier Ringer'], 'avg_rating': None}
# {'_id': ['Vicente Aranda'], 'avg_rating': 5.716666666666666}
# {'_id': ['Joe Anderson'], 'avg_rating': 7.9}
# {'_id': ['Koen Mortier'], 'avg_rating': 7.1}
# {'_id': ['Cecèlia Amado', 'Guy Gonèalves'], 'avg_rating': 6.2}
# {'_id': ['Anthony Mann', 'Charles Walters'], 'avg_rating': 6.4}
# {'_id': ['Elia Petridis'], 'avg_rating': 6.1}
# {'_id': ['Peter Payer'], 'avg_rating': 5.4}
# {'_id': ['Keith Hartman'], 'avg_rating': 6.6}
# {'_id': ['Tomoyuki Takimoto'], 'avg_rating': 6.9}
# {'_id': ['Robert Ellis Miller'], 'avg_rating': 7.35}
# {'_id': ['Pere Portabella'], 'avg_rating': 6.8}
# {'_id': ['Bill Fishman'], 'avg_rating': 2.4}
# {'_id': ['Anders Grènros'], 'avg_rating': 6.2}
# {'_id': ['James Signorelli'], 'avg_rating': 6.3}
# {'_id': ['Zam Salim'], 'avg_rating': 7.3}
# {'_id': ['Sandra Nettelbeck'], 'avg_rating': 6.866666666666667}
# {'_id': ['Katie Wolfe'], 'avg_rating': 6.0}
# {'_id': ['Bertha Bay-Sa Pan'], 'avg_rating': 6.4}
# {'_id': ['Richard Wenk'], 'avg_rating': 5.65}
# {'_id': ['Carlo Vanzina'], 'avg_rating': 4.55}
# {'_id': ['Amanda Wilder'], 'avg_rating': 7.2}
# {'_id': ['Antonio Santini', 'Dan Sickles'], 'avg_rating': 5.0}
# {'_id': ['John Dullaghan'], 'avg_rating': 7.9}
# {'_id': ['Carles Torrens'], 'avg_rating': 5.1}
# {'_id': ['Vincenzo Natali'], 'avg_rating': 6.44}
# {'_id': ['Arab Nasser', 'Tarzan Nasser'], 'avg_rating': 6.5}
# {'_id': ['Louise Archambault'], 'avg_rating': 6.9}
# {'_id': ['Takashi Shimizu'], 'avg_rating': 5.86}
# {'_id': ['Richard Raaphorst'], 'avg_rating': 5.3}
# {'_id': ['John Schultz'], 'avg_rating': 5.033333333333333}
# {'_id': ['Mark Hamill'], 'avg_rating': 5.9}
# {'_id': ['Maurice Pialat'], 'avg_rating': 7.2}
# {'_id': ['Claude Cloutier'], 'avg_rating': 7.8}
# {'_id': ['Ivan Boeckmans', 'Guy Lee Thys'], 'avg_rating': 5.8}
# {'_id': ['Delmer Daves', 'Karl Malden', 'Vincent Sherman'], 'avg_rating': 7.2}
# {'_id': ['Rodney Ascher'], 'avg_rating': 6.1}
# {'_id': ['Menelaos Karamaghiolis'], 'avg_rating': 6.9}
# {'_id': ['Fredrik Edfeldt'], 'avg_rating': 6.2}
# {'_id': ['Richard Spence'], 'avg_rating': 7.1}
# {'_id': ['Bernard Borderie'], 'avg_rating': 6.9}
# {'_id': ['Nurit Kedar'], 'avg_rating': 6.8}
# {'_id': ['Benson Lee'], 'avg_rating': 6.733333333333333}
# {'_id': ['Justin Kelly'], 'avg_rating': 6.5}
# {'_id': ['Serdar Akar'], 'avg_rating': 7.55}
# {'_id': ['Mike Newell'], 'avg_rating': 6.573333333333333}
# {'_id': ['Basil Dearden'], 'avg_rating': 7.2}
# {'_id': ['Bob Odenkirk'], 'avg_rating': 6.199999999999999}
# {'_id': ['Leni Riefenstahl', 'Bèla Balèzs'], 'avg_rating': 7.0}
# {'_id': ['Jerzy Kawalerowicz'], 'avg_rating': 7.2}
# {'_id': ['Philip Frank Messina'], 'avg_rating': 5.9}
# {'_id': ['Joe Lynch'], 'avg_rating': 5.6}
# {'_id': ['Mohamed El Aboudi'], 'avg_rating': 5.8}
# {'_id': ['Til Schweiger', 'Lars Gmehling'], 'avg_rating': 6.8}
# {'_id': ['Mateo Gil'], 'avg_rating': 6.3}
# {'_id': ['Alain Fresnot'], 'avg_rating': 7.0}
# {'_id': ['Peter Bogdanovich'], 'avg_rating': 7.2272727272727275}
# {'_id': ['Jon Hurwitz', 'Hayden Schlossberg'], 'avg_rating': 6.75}
# {'_id': ['Norman Ferguson', 'T. Hee', 'Wilfred Jackson', 'Jack Kinney', 'Hamilton Luske', 'Bill Roberts', 'Ben Sharpsteen'], 'avg_rating': 7.5}
# {'_id': ['George Miller', 'George Ogilvie'], 'avg_rating': 6.2}
# {'_id': ['Francesco Bruni'], 'avg_rating': 6.35}
# {'_id': ['Sandro Aguilar'], 'avg_rating': 5.3}
# {'_id': ['Ki-hyeong Park'], 'avg_rating': 6.0}
# {'_id': ['Declan Lowney'], 'avg_rating': 6.5}
# {'_id': ['Ferran Brooks', 'Kevin Macdonald', 'Alejandro Romeo', 'Hiroaki Aikawa', 'Natalia Andreadis', 'Jack Attridge', 'Cristina Bocchialini', 'Zillah Bowes', 'Andrea Dalla Costa', 'Lisa Cottrell-Bentley', 'Alejo Crisèstomo', 'Ayman El Gazwy', 'Jane Haubrich', 'Soma Helmi', 'Jennifer M. Howd', 'Aditya Kolli', 'Gabor Kukucska', 'Francesco La Regina', 'Frederic Lumiere', 'Marek Mackovic', 'Linda Matarasso', 'Kevin McMahon', 'Joseph Michael', 'Joaquin Montalvan', 'Lilit Movsisyan', 'Emmanuelle Pickett', 'Alaa Sheikh Hassan', 'Marcus Tedenryd', 'Zuqy'], 'avg_rating': 7.7}
# {'_id': ['Damian Nenow'], 'avg_rating': 7.5}
# {'_id': ['Jeff Lew'], 'avg_rating': 7.3}
# {'_id': ['Martti Helde'], 'avg_rating': 7.9}
# {'_id': ['Darren Doane'], 'avg_rating': 1.6}
# {'_id': ['Patrice Chèreau'], 'avg_rating': 6.720000000000001}
# {'_id': ['Jonathan Hensleigh'], 'avg_rating': 6.5}
# {'_id': ['Janez Burger'], 'avg_rating': 7.2}
# {'_id': ['Mark Jarrett'], 'avg_rating': 6.0}
# {'_id': ['Yurek Bogayevicz'], 'avg_rating': 6.75}
# {'_id': ['Jean Vigo'], 'avg_rating': 7.5}
# {'_id': ['Stefan Scaini'], 'avg_rating': 6.8}
# {'_id': ['Ilisa Barbash', 'Lucien Castaing-Taylor'], 'avg_rating': 6.9}
# {'_id': ['Harun Farocki'], 'avg_rating': 7.3}
# {'_id': ['Marcelo Epstein'], 'avg_rating': 3.7}
# {'_id': ['Julie Delpy'], 'avg_rating': 6.4}
# {'_id': ['Caveh Zahedi'], 'avg_rating': 6.1}
# {'_id': ['Marc Riba', 'Anna Solanas'], 'avg_rating': 7.2}
# {'_id': ['Hyun-seok Kim'], 'avg_rating': 6.8}
# {'_id': ['Jorge Torregrossa'], 'avg_rating': 5.7}
# {'_id': ['Clenet Verdi-Rose'], 'avg_rating': 8.2}
# {'_id': ['Aisling Walsh'], 'avg_rating': 6.35}
# {'_id': ['Daniel Hsia'], 'avg_rating': 6.3}
# {'_id': ['Byambasuren Davaa'], 'avg_rating': 7.7}
# {'_id': ['Darren Paul Fisher'], 'avg_rating': 6.9}
# {'_id': ['Peter Mettler'], 'avg_rating': 6.933333333333334}
# {'_id': ['Candida Brady'], 'avg_rating': 7.5}
# {'_id': ['Mari Rantasila'], 'avg_rating': 5.166666666666667}
# {'_id': ['Nisha Ganatra'], 'avg_rating': 5.5}
# {'_id': ['Louis C.K.'], 'avg_rating': 7.7}
# {'_id': ['Perry Blackshear'], 'avg_rating': 7.6}
# {'_id': ['Sèrgio Trèfaut'], 'avg_rating': 6.8}
# {'_id': ['Terry Green'], 'avg_rating': 6.300000000000001}
# {'_id': ['Zacharias Kunuk'], 'avg_rating': 7.5}
# {'_id': ['Jèlèus Kemp'], 'avg_rating': 4.9}
# {'_id': ['Brendan Fletcher'], 'avg_rating': 6.5}
# {'_id': ['Geeta Patel', 'Ravi Patel'], 'avg_rating': 8.1}
# {'_id': ['Madeleine Olnek'], 'avg_rating': 6.1}
# {'_id': ['Charles Bryant', 'Alla Nazimova'], 'avg_rating': 6.6}
# {'_id': ['Martin Bell'], 'avg_rating': 7.550000000000001}
# {'_id': ['Jane Campion'], 'avg_rating': 6.65}
# {'_id': ['Tso-chi Chang'], 'avg_rating': 7.166666666666667}
# {'_id': ['Paquito Del Bosco'], 'avg_rating': 6.6}
# {'_id': ["Patrick O'Brien"], 'avg_rating': 7.2}
# {'_id': ['Shin-yeon Won'], 'avg_rating': 6.9}
# {'_id': ['Jakov Sedlar'], 'avg_rating': 5.2}
# {'_id': ['Chris Hegedus', 'Jehane Noujaim'], 'avg_rating': 7.1}
# {'_id': ['Eugene Corr'], 'avg_rating': 6.6}
# {'_id': ['Gianluca Maria Tavarelli'], 'avg_rating': 6.2}
# {'_id': ['Osamu Tezuka'], 'avg_rating': 7.3}
# {'_id': ['Argyris Papadimitropoulos', 'Jan Vogel'], 'avg_rating': 6.0}
# {'_id': ['Sheldon Lettich'], 'avg_rating': 5.4}
# {'_id': ['Gert de Graaff'], 'avg_rating': 7.2}
# {'_id': ['Harry Winer'], 'avg_rating': 5.65}
# {'_id': ['Tim R. Lea'], 'avg_rating': 7.0}
# {'_id': ['Giuliano Montaldo'], 'avg_rating': 6.788888888888889}
# {'_id': ['Esther Robinson'], 'avg_rating': 6.9}
# {'_id': ['Erik Lèchen'], 'avg_rating': 7.4}
# {'_id': ['Gordon Parks Jr.'], 'avg_rating': 6.5}
# {'_id': ['Guillermo del Toro'], 'avg_rating': 7.0}
# {'_id': ['Fred Andrews'], 'avg_rating': 3.7}
# {'_id': ['Marin Karmitz'], 'avg_rating': 7.1}
# {'_id': ['Casey Walker'], 'avg_rating': 5.3}
# {'_id': ['Henk Pretorius'], 'avg_rating': 6.5}
# {'_id': ['Steve Goltz'], 'avg_rating': 4.1}
# {'_id': ['Tina Valinsky'], 'avg_rating': 5.1}
# {'_id': ['Joe Stauffer'], 'avg_rating': 6.1}
# {'_id': ['Walon Green'], 'avg_rating': 6.7}
# {'_id': ['Gary Fleder'], 'avg_rating': 6.685714285714285}
# {'_id': ['Kodi Ramakrishna'], 'avg_rating': 7.2}
# {'_id': ['Tom Ford'], 'avg_rating': 7.6}
# {'_id': ['Abdallah Omeish', 'Sufyan Omeish'], 'avg_rating': 8.3}
# {'_id': ['Luca Barbareschi'], 'avg_rating': 3.7}
# {'_id': ['Punit Malhotra'], 'avg_rating': 5.6}
# {'_id': ['Donald Crombie'], 'avg_rating': 5.7}
# {'_id': ['Arna Selznick'], 'avg_rating': 5.5}
# {'_id': ['Elissa Down'], 'avg_rating': 7.3}
# {'_id': ['Taavi Kassila'], 'avg_rating': 6.0}
# {'_id': ['Dan Scanlon'], 'avg_rating': 7.4}
# {'_id': ['Fred Zinnemann'], 'avg_rating': 7.471428571428571}
# {'_id': ['Joe Medeiros'], 'avg_rating': 7.4}
# {'_id': ['Karin Babinskè'], 'avg_rating': 6.1}
# {'_id': ['Anthony Howarth'], 'avg_rating': 8.0}
# {'_id': ['Luigi Zampa'], 'avg_rating': 6.9}
# {'_id': ['Hrishikesh Mukherjee'], 'avg_rating': 7.6}
# {'_id': ['Dexter Fletcher'], 'avg_rating': 6.85}
# {'_id': ['Chris Weitz'], 'avg_rating': 5.966666666666666}
# {'_id': ['Ming-liang Tsai'], 'avg_rating': 7.164285714285714}
# {'_id': ['Jean Delannoy'], 'avg_rating': 7.25}
# {'_id': ['John Ridley'], 'avg_rating': 5.05}
# {'_id': ['Martèn Carranza', 'Victoria Galardi'], 'avg_rating': 5.9}
# {'_id': ['George Bessudo'], 'avg_rating': 5.6}
# {'_id': ['Kjell-èke Andersson'], 'avg_rating': 6.4}
# {'_id': ['Charlie Paul'], 'avg_rating': 6.9}
# {'_id': ['Heywood Gould'], 'avg_rating': 5.8}
# {'_id': ['Andrzej Sekula'], 'avg_rating': 5.6}
# {'_id': ['Christian Alvart'], 'avg_rating': 6.5}
# {'_id': ['Don Roos'], 'avg_rating': 6.233333333333333}
# {'_id': ['Charles Lane'], 'avg_rating': 7.2}
# {'_id': ['Duncan Jones'], 'avg_rating': 7.75}
# {'_id': ['Adrian Pasdar'], 'avg_rating': 7.9}
# {'_id': ['James Frawley'], 'avg_rating': 6.733333333333333}
# {'_id': ['Jamie Thraves'], 'avg_rating': 6.733333333333334}
# {'_id': ['David Hackl'], 'avg_rating': 5.8}
# {'_id': ['Alex Law'], 'avg_rating': 7.45}
# {'_id': ['Sermiyan Midyat'], 'avg_rating': 5.7}
# {'_id': ['Vyacheslav Ross'], 'avg_rating': 7.7}
# {'_id': ['Justin Zackham'], 'avg_rating': 5.6}
# {'_id': ['Pierre Granier-Deferre'], 'avg_rating': 6.9}
# {'_id': ['Norman Mailer'], 'avg_rating': 4.7}
# {'_id': ['Robert Moore'], 'avg_rating': 6.7}
# {'_id': ['Wayne Wang'], 'avg_rating': 6.236363636363635}
# {'_id': ['Ram Gopal Varma'], 'avg_rating': 6.666666666666667}
# {'_id': ['Anthony Wonke'], 'avg_rating': 7.4}
# {'_id': ['Syllas Tzoumerkas'], 'avg_rating': 6.1}
# {'_id': ['Michael Laughlin'], 'avg_rating': 5.5}
# {'_id': ['Peter Askin'], 'avg_rating': 7.5}
# {'_id': ['Curtis Bernhardt', 'Busby Berkeley'], 'avg_rating': 7.3}
# {'_id': ['Peter Cohen'], 'avg_rating': 8.0}
# {'_id': ['Josefina Molina'], 'avg_rating': 7.9}
# {'_id': ['Jon Sherman'], 'avg_rating': 4.0}
# {'_id': ['Evgeniy Bedarev'], 'avg_rating': 6.4}
# {'_id': ['Tony Ayres'], 'avg_rating': 6.95}
# {'_id': ['David Steinberg'], 'avg_rating': 6.0}
# {'_id': ['Johan van der Keuken'], 'avg_rating': 7.9}
# {'_id': ['Susan Stroman'], 'avg_rating': 6.4}
# {'_id': ['Zach Clark'], 'avg_rating': 5.7}
# {'_id': ['Mark Pellington'], 'avg_rating': 6.38}
# {'_id': ['Dana Nachman'], 'avg_rating': 5.8}
# {'_id': ['J. Miles Dale'], 'avg_rating': 4.8}
# {'_id': ['Sean Mullin'], 'avg_rating': 6.2}
# {'_id': ['Paul Kenworthy', 'Ralph Wright'], 'avg_rating': 7.1}
# {'_id': ['Buster Keaton'], 'avg_rating': 7.62}
# {'_id': ['Helmut Dietl'], 'avg_rating': 6.0}
# {'_id': ['Doug Pray'], 'avg_rating': 7.425}
# {'_id': ['Richard Day'], 'avg_rating': 6.75}
# {'_id': ['Peter Fonda'], 'avg_rating': 7.1}
# {'_id': ['Janet Grillo'], 'avg_rating': 6.1}
# {'_id': ['Steven C. Miller'], 'avg_rating': 5.9}
# {'_id': ['Dominic Murphy'], 'avg_rating': 7.0}
# {'_id': ['Nacho G. Velilla'], 'avg_rating': 6.3}
# {'_id': ['Stèphane Berla', 'Mathias Malzieu'], 'avg_rating': 7.0}
# {'_id': ['Tom Hanks'], 'avg_rating': 6.4}
# {'_id': ['Riccardo Donna'], 'avg_rating': 4.3}
# {'_id': ['Simon Jaquemet'], 'avg_rating': 7.0}
# {'_id': ['Sulev Keedus'], 'avg_rating': 6.7}
# {'_id': ['Karen Disher'], 'avg_rating': 6.5}
# {'_id': ['Alexander Korda'], 'avg_rating': 7.05}
# {'_id': ['Nithiwat Tharathorn'], 'avg_rating': 7.9}
# {'_id': ['Vincent Garenq'], 'avg_rating': 7.3}
# {'_id': ['T.J. Amato', 'Josh Mills'], 'avg_rating': 5.2}
# {'_id': ['Jimmy Hayward'], 'avg_rating': 5.25}
# {'_id': ['Francis Glebas'], 'avg_rating': 5.9}
# {'_id': ['Jen Soska', 'Sylvia Soska'], 'avg_rating': 5.55}
# {'_id': ['Franèois Desagnat', 'Thomas Sorriaux'], 'avg_rating': 4.5}
# {'_id': ['Michael Reeves'], 'avg_rating': 6.9}
# {'_id': ['Steve Hudson'], 'avg_rating': 6.9}
# {'_id': ['Anson Hartford', 'Hugh Hartford'], 'avg_rating': 7.2}
# {'_id': ['Mohammad Rasoulof'], 'avg_rating': 7.175}
# {'_id': ['Paul Hough'], 'avg_rating': 6.300000000000001}
# {'_id': ['Toa Fraser'], 'avg_rating': 6.766666666666667}
# {'_id': ['Bill Condon'], 'avg_rating': 6.457142857142857}
# {'_id': ['Andrzej Zulawski'], 'avg_rating': 6.88}
# {'_id': ['Kristina Buozyte'], 'avg_rating': 6.1}
# {'_id': ['Laèla Marrakchi'], 'avg_rating': 6.6}
# {'_id': ['Chris Messina'], 'avg_rating': 5.9}
# {'_id': ['J. Mills Goodloe'], 'avg_rating': 6.4}
# {'_id': ['Hong-soo Park'], 'avg_rating': 6.8}
# {'_id': ['Frèdèric Tcheng'], 'avg_rating': 7.2}
# {'_id': ['Juan Antonio Bardem'], 'avg_rating': 7.333333333333333}
# {'_id': ['Henri Colpi'], 'avg_rating': 7.2}
# {'_id': ['Fred Barzyk'], 'avg_rating': 7.3}
# {'_id': ['Gordon Parks'], 'avg_rating': 6.9}
# {'_id': ['Karin Julsrud'], 'avg_rating': 6.0}
# {'_id': ['Renè Goscinny', 'Albert Uderzo'], 'avg_rating': 7.2}
# ...
# {'_id': ['Chris Sivertson'], 'avg_rating': 4.8}
# {'_id': ['David Langlitz'], 'avg_rating': 6.4}
# {'_id': ['Olias Barco'], 'avg_rating': 6.4}
# {'_id': ['Carl Schenkel'], 'avg_rating': 6.05}
# {'_id': ['Allen Wolf'], 'avg_rating': 5.5}
# {'_id': ['McKay Daines'], 'avg_rating': 4.3}
# {'_id': ['Sebastian Grobler'], 'avg_rating': 6.8}
# {'_id': ['Hayao Miyazaki'], 'avg_rating': 8.052941176470588}
# {'_id': ['Steffen Haars', 'Flip Van der Kuil'], 'avg_rating': 6.233333333333334}
# {'_id': ['Tony Jaa', 'Panna Rittikrai'], 'avg_rating': 5.550000000000001}
# {'_id': ['Irakli Kvirikadze'], 'avg_rating': 8.3}
# {'_id': ['Andrew Wagner'], 'avg_rating': 6.15}
# {'_id': ['Ed Burke', 'Beyoncè Knowles', 'Ilan Y. Benatar'], 'avg_rating': 6.3}
# {'_id': ['Grant Baldwin'], 'avg_rating': 7.5}
# {'_id': ['Celina Murga'], 'avg_rating': 6.3}
# {'_id': ['Greg Lombardo'], 'avg_rating': 5.6}
# {'_id': ['Steve Jacobs'], 'avg_rating': 6.6}
# {'_id': ['Tian-Ming Wu'], 'avg_rating': 7.6}
# {'_id': ['Garson Kanin'], 'avg_rating': 6.9}
# {'_id': ['Chris Landreth'], 'avg_rating': 7.7}
# {'_id': ['Andrea Martènez Crowther'], 'avg_rating': 6.9}
# {'_id': ['Michael J.F. Scott'], 'avg_rating': 6.8}
# {'_id': ['Filip Van Neyghem'], 'avg_rating': 5.8}
# {'_id': ['Hua-Tao Teng'], 'avg_rating': 5.6}
# {'_id': ['Robert J. Rosenthal'], 'avg_rating': 4.7}
# {'_id': ['Daniel Grou'], 'avg_rating': 6.1}
# {'_id': ['N. Krishna'], 'avg_rating': 6.6}
# {'_id': ['Micki Dickoff', 'Tony Pagano'], 'avg_rating': 7.5}
# {'_id': ['Derek Franson'], 'avg_rating': 4.9}
# {'_id': ['Rudi Van Den Bossche'], 'avg_rating': 4.6}
# {'_id': ['Josè Ramèn Larraz'], 'avg_rating': 6.5}
# {'_id': ['Warren Beatty'], 'avg_rating': 6.8}
# {'_id': ['Wim Wenders'], 'avg_rating': 7.01304347826087}
# {'_id': ['Stephen Surjik'], 'avg_rating': 7.1}
# {'_id': ['Philip Grèning'], 'avg_rating': 5.7}
# {'_id': ['Jack Donohue'], 'avg_rating': 6.3}
# {'_id': ['Emir Kusturica'], 'avg_rating': 7.677777777777777}
# {'_id': ['Scott Leberecht'], 'avg_rating': 5.9}
# {'_id': ['John Moore'], 'avg_rating': 5.74}
# {'_id': ['Peter Wade'], 'avg_rating': 4.9}
# {'_id': ['Jouni Hokkanen'], 'avg_rating': 6.1}
# {'_id': ['Cory Krueckeberg'], 'avg_rating': 7.1}
# {'_id': ['Oscar Rodrigues Alves', 'Branco Mello'], 'avg_rating': 7.4}
# {'_id': ['Johnnie To', 'Ka-Fai Wai'], 'avg_rating': 6.8375}
# {'_id': ['Gustavo Nieto Roa'], 'avg_rating': 5.3}
# {'_id': ['Jacques Rivette'], 'avg_rating': 7.421428571428572}
# {'_id': ['Craig Gillespie'], 'avg_rating': 6.966666666666666}
# {'_id': ['Philippe Lioret'], 'avg_rating': 7.2}
# {'_id': ['Dave Thomas'], 'avg_rating': 5.6}
# {'_id': ['John Roberts'], 'avg_rating': 6.766666666666667}
# {'_id': ['John Hamburg'], 'avg_rating': 6.5}
# {'_id': ['Brad T. Gottfred'], 'avg_rating': 6.5}
# {'_id': ['Steven Ascher', 'Jeanne Jordan'], 'avg_rating': 7.5}
# {'_id': ['Bob Byington'], 'avg_rating': 6.166666666666667}
# {'_id': ['Giacomo Battiato'], 'avg_rating': 5.8}
# {'_id': ['Tony Mahony', 'Angus Sampson'], 'avg_rating': 6.3}
# {'_id': ['Owen Hurley', 'Kris Zimmerman'], 'avg_rating': 4.5}
# {'_id': ['Justin Dec'], 'avg_rating': 6.4}
# {'_id': ['Jens Jonsson'], 'avg_rating': 6.35}
# {'_id': ['Stanley Kubrick'], 'avg_rating': 7.825}
# {'_id': ['Dianne Jackson', 'Jimmy T. Murakami'], 'avg_rating': 8.2}
# {'_id': ['Gabe Ibèèez'], 'avg_rating': 5.9}
# {'_id': ['William Riead'], 'avg_rating': 8.5}
# {'_id': ['Nitesh Tiwari'], 'avg_rating': 7.0}
# {'_id': ['Fernando Gonzèlez Molina'], 'avg_rating': 6.333333333333333}
# {'_id': ['Harry Dodge', 'Silas Howard'], 'avg_rating': 5.7}
# {'_id': ['Helmut Kèutner'], 'avg_rating': 7.15}
# {'_id': ['Martine Dugowson'], 'avg_rating': 6.65}
# {'_id': ['Michael Goguen'], 'avg_rating': 6.9}
# {'_id': ['Bob Gosse'], 'avg_rating': 6.6}
# {'_id': ['Neil Burger'], 'avg_rating': 7.1}
# {'_id': ['Fèlix Viscarret'], 'avg_rating': 6.5}
# {'_id': ['Mikio Naruse'], 'avg_rating': 7.8125}
# {'_id': ['Chris Angel'], 'avg_rating': 3.75}
# {'_id': ['Gene Wilder'], 'avg_rating': 5.6}
# {'_id': ['Marty Callner', 'Bill Crooks'], 'avg_rating': 8.5}
# {'_id': ['Kazuya Konaka'], 'avg_rating': 6.8}
# {'_id': ['Johannes Roberts'], 'avg_rating': 4.4}
# {'_id': ['Nathaniel Kahn'], 'avg_rating': 7.4}
# {'_id': ['Henry Selick'], 'avg_rating': 6.775}
# {'_id': ['Dariusz Jablonski'], 'avg_rating': 7.0}
# {'_id': ['Victor Schertzinger'], 'avg_rating': 6.633333333333333}
# {'_id': ['Peter Meyer'], 'avg_rating': 7.4}
# {'_id': ['Daniel Lind Lagerlèf'], 'avg_rating': 6.05}
# {'_id': ['Robbins Barstow'], 'avg_rating': 6.3}
# {'_id': ['Jenny Deller'], 'avg_rating': 6.0}
# {'_id': ['Karin Fahlèn'], 'avg_rating': 6.0}
# {'_id': ['Niels Mueller'], 'avg_rating': 7.0}
# {'_id': ['Mark Zakharov'], 'avg_rating': 8.1}
# {'_id': ['Craig Mazin'], 'avg_rating': 4.5}
# {'_id': ['Sarah Polley'], 'avg_rating': 7.266666666666666}
# {'_id': ['Vito Rocco'], 'avg_rating': 6.4}
# {'_id': ['Fernando Colomo'], 'avg_rating': 6.05}
# {'_id': ['Dunya Smirnova'], 'avg_rating': 6.9}
# {'_id': ['Kevin Brownlow', 'Andrew Mollo'], 'avg_rating': 6.8}
# {'_id': ['Laetitia Masson'], 'avg_rating': 6.699999999999999}
# {'_id': ['David Thacker'], 'avg_rating': 7.9}
# {'_id': ['Janicza Bravo'], 'avg_rating': 6.5}
# {'_id': ['Sidney Gilliat'], 'avg_rating': 6.9}
# {'_id': ['Yi-chi Lien'], 'avg_rating': 6.0}
# {'_id': ['N.C. Heikin'], 'avg_rating': 6.9}
# {'_id': ['D.A. Pennebaker'], 'avg_rating': 8.05}
# {'_id': ['Ben Chessell'], 'avg_rating': None}
# {'_id': ['Raman Hui'], 'avg_rating': 7.15}
# {'_id': ['Bill Kroyer'], 'avg_rating': 6.4}
# {'_id': ['Steven Maler'], 'avg_rating': 6.5}
# {'_id': ['Bill Morrison'], 'avg_rating': 6.966666666666666}
# {'_id': ['Goran Radovanovic'], 'avg_rating': 7.8}
# {'_id': ['Peter Ustinov'], 'avg_rating': 7.199999999999999}
# {'_id': ['Pieter Van Hees'], 'avg_rating': 6.35}
# {'_id': ['Kristy Guevara-Flanagan'], 'avg_rating': 7.5}
# {'_id': ['Bennett Miller'], 'avg_rating': 7.475}
# {'_id': ['Joe Dante', 'John Landis', 'George Miller', 'Steven Spielberg'], 'avg_rating': 6.5}
# {'_id': ['Sean Hogan', 'Andrew Parkinson', 'Simon Rumley'], 'avg_rating': 4.7}
# {'_id': ['Adrièn Biniez'], 'avg_rating': 6.8}
# {'_id': ['Cary Joji Fukunaga'], 'avg_rating': 7.6}
# {'_id': ['Larry Peerce'], 'avg_rating': 6.8}
# {'_id': ['Iain Softley'], 'avg_rating': 6.779999999999999}
# {'_id': ['Heikki Kossi'], 'avg_rating': 7.0}
# {'_id': ['Raja Amari'], 'avg_rating': 6.7}
# {'_id': ['Terry Benedict'], 'avg_rating': 8.1}
# {'_id': ['Alain Tanner'], 'avg_rating': 7.133333333333333}
# {'_id': ['Kinka Usher'], 'avg_rating': 6.0}
# {'_id': ['Ben Wheatley'], 'avg_rating': 6.35}
# {'_id': ['Stobe Harju'], 'avg_rating': 6.2}
# {'_id': ['Albert Maysles'], 'avg_rating': 6.5}
# {'_id': ['Luis Ortega'], 'avg_rating': 4.9}
# {'_id': ['Riley Stearns'], 'avg_rating': 6.6}
# {'_id': ['Rèmi Bezanèon', 'Jean-Christophe Lie'], 'avg_rating': 6.7}
# {'_id': ['Gary Halvorson'], 'avg_rating': 5.7}
# {'_id': ['Jianbin Chen'], 'avg_rating': 7.7}
# {'_id': ['Gabriel Axel'], 'avg_rating': 7.35}
# {'_id': ['Noah Buschel'], 'avg_rating': 6.066666666666666}
# {'_id': ['Jean-Jacques Beineix'], 'avg_rating': 6.7}
# {'_id': ['Francesca Comencini'], 'avg_rating': 6.0}
# {'_id': ['Mark Malone'], 'avg_rating': 5.4}
# {'_id': ['Anthony Waller'], 'avg_rating': 5.949999999999999}
# {'_id': ['Patrik-Ian Polk'], 'avg_rating': 6.7}
# {'_id': ['Kadri Kèusaar'], 'avg_rating': 6.0}
# {'_id': ['Daniel Mann'], 'avg_rating': 6.945454545454546}
# {'_id': ['Peter Chan', 'Wai Man Yip'], 'avg_rating': 7.1}
# {'_id': ['Khavn', 'Khavn'], 'avg_rating': 6.2}
# {'_id': ['Jerome Sable'], 'avg_rating': 5.2}
# {'_id': ['Vikas Bahl'], 'avg_rating': 8.5}
# {'_id': ['Claude Goretta'], 'avg_rating': 7.9}
# {'_id': ['Joseph B. Vasquez'], 'avg_rating': 7.0}
# {'_id': ['Zak Forsman'], 'avg_rating': 5.1}
# {'_id': ['Scott Cohen'], 'avg_rating': 5.1}
# {'_id': ['Jerome Robbins', 'Robert Wise'], 'avg_rating': 7.6}
# {'_id': ['Katrin Ottarsdèttir'], 'avg_rating': 6.5}
# {'_id': ['Laura Bispuri'], 'avg_rating': 6.4}
# {'_id': ['Linda Goldstein Knowlton', 'Linda Hawkins'], 'avg_rating': 7.4}
# {'_id': ['Jacques Thelemaque'], 'avg_rating': 6.7}
# {'_id': ['Erik Gandini', 'Tarik Saleh'], 'avg_rating': 7.05}
# {'_id': ['Ben Drew'], 'avg_rating': 7.0}
# {'_id': ['Jennifer M. Kroot'], 'avg_rating': 6.9}
# {'_id': ['Eric Rohmer'], 'avg_rating': 7.445}
# {'_id': ['Jirè Trnka'], 'avg_rating': 7.3}
# {'_id': ['Gorè Miyazaki'], 'avg_rating': 7.1000000000000005}
# {'_id': ['Ilkka Jèrvi-Laturi'], 'avg_rating': 7.0}
# {'_id': ['Jennifer Yuh'], 'avg_rating': 7.3}
# {'_id': ['Anna Axster'], 'avg_rating': 5.4}
# {'_id': ['Brad Bird'], 'avg_rating': 7.540000000000001}
# {'_id': ['Tarik Saleh'], 'avg_rating': 6.3}
# {'_id': ['James Algar'], 'avg_rating': 7.26}
# {'_id': ['Steven Sawalich'], 'avg_rating': 7.4}
# {'_id': ['Noel M. Smith'], 'avg_rating': 6.7}
# {'_id': ['Alessandro Piva'], 'avg_rating': 6.4}
# {'_id': ['Yair Landau'], 'avg_rating': 7.7}
# {'_id': ['Michael McCullers'], 'avg_rating': 6.1}
# {'_id': ['Jerzy Domaradzki'], 'avg_rating': 6.9}
# {'_id': ['Richard Jobson'], 'avg_rating': 6.0}
# {'_id': ['Konstantin Maksimov'], 'avg_rating': 3.8}
# {'_id': ['Janus Metz Pedersen'], 'avg_rating': 7.6}
# {'_id': ['Gerald Potterton', 'Buster Keaton', 'John Spotton'], 'avg_rating': 7.5}
# {'_id': ['Aubrey Nealon'], 'avg_rating': 6.7}
# {'_id': ['Didi Danquart'], 'avg_rating': 5.9}
# {'_id': ['Josef von Bèky'], 'avg_rating': 7.1}
# {'_id': ['Jeremy Gardner'], 'avg_rating': 6.4}
# {'_id': ['Karthik Subbaraj'], 'avg_rating': 8.3}
# {'_id': ['Stig Bjèrkman'], 'avg_rating': 7.4}
# {'_id': ['Jèzè Itami'], 'avg_rating': 7.214285714285714}
# {'_id': ['Ernie Barbarash'], 'avg_rating': 5.5}
# {'_id': ['Jerusha Hess'], 'avg_rating': 6.2}
# {'_id': ['Jonathan Sobol'], 'avg_rating': 6.35}
# {'_id': ['Petra Costa', 'Lea Glob'], 'avg_rating': 7.8}
# {'_id': ['Anne Fontaine'], 'avg_rating': 6.471428571428571}
# {'_id': ['Dennie Gordon'], 'avg_rating': 5.575}
# {'_id': ['Roger Kumble'], 'avg_rating': 5.220000000000001}
# {'_id': ['Dana Lustig'], 'avg_rating': 4.449999999999999}
# {'_id': ['Susanna Fogel'], 'avg_rating': 6.2}
# {'_id': ['Charles Grosvenor'], 'avg_rating': 5.957142857142857}
# {'_id': ['Shyam Benegal'], 'avg_rating': 7.7}
# {'_id': ['Mimi Leder'], 'avg_rating': 6.366666666666667}
# {'_id': ['Ilkka Vanne'], 'avg_rating': 6.033333333333334}
# {'_id': ['Joshua Lim'], 'avg_rating': 5.0}
# {'_id': ['Junji Sakamoto'], 'avg_rating': 6.7}
# {'_id': ['Kèki Mitani'], 'avg_rating': 7.233333333333334}
# {'_id': ['Zack Coffman', 'Scott Di Lalla'], 'avg_rating': 8.1}
# {'_id': ['Robert Marcarelli'], 'avg_rating': 6.1}
# {'_id': ['Radek Wegrzyn'], 'avg_rating': 6.6}
# {'_id': ['Carla Garapedian'], 'avg_rating': 6.75}
# {'_id': ['Joseph Barbera', 'William Hanna'], 'avg_rating': 6.85}
# {'_id': ['Toe Yuen'], 'avg_rating': 7.4}
# {'_id': ['Liisa Helminen'], 'avg_rating': 6.1}
# {'_id': ['Rick Moranis', 'Dave Thomas'], 'avg_rating': 6.8}
# {'_id': ['Anthony Joseph Giunta'], 'avg_rating': 5.5}
# {'_id': ['Albert Maysles', 'Lynn True', 'David Usui', 'Nelson Walker III', 'Benjamin Wu'], 'avg_rating': 6.5}
# {'_id': ['Paul Grimault'], 'avg_rating': 8.0}
# {'_id': ['Luca Miniero'], 'avg_rating': 5.85}
# {'_id': ['Nikos Panayotopoulos'], 'avg_rating': 7.3}
# {'_id': ['Gustav Ucicky', 'Emil Jannings'], 'avg_rating': 6.7}
# {'_id': ['Seth Kramer', 'Daniel A. Miller', 'Jeremy Newberger'], 'avg_rating': 7.199999999999999}
# {'_id': ['Stephen Chow', 'Vincent Kok'], 'avg_rating': 7.1}
# {'_id': ['AJ Schnack'], 'avg_rating': 7.550000000000001}
# {'_id': ['Gèrard Pirès'], 'avg_rating': 6.9}
# {'_id': ['Marilyn Agrelo'], 'avg_rating': 6.45}
# {'_id': ['Prabhudheva'], 'avg_rating': 5.825}
# {'_id': ['Jean-Pierre Blanc'], 'avg_rating': 6.7}
# {'_id': ['Aimee Lagos'], 'avg_rating': 5.7}
# {'_id': ['Gustav Hofer', 'Luca Ragazzi'], 'avg_rating': 6.85}
# {'_id': ['Sung-ho Kim'], 'avg_rating': 6.5}
# {'_id': ['Chris Weitz', 'Paul Weitz'], 'avg_rating': 6.25}
# {'_id': ['Damir Lukacevic'], 'avg_rating': 6.8}
# {'_id': ['Charlotte Zwerin'], 'avg_rating': 7.7}
# {'_id': ['Freida Lee Mock', 'Terry Sanders'], 'avg_rating': 8.1}
# {'_id': ['Raymond Lee', 'Siu-Tung Ching', 'Hark Tsui'], 'avg_rating': 7.4}
# {'_id': ['Mila Turajlic'], 'avg_rating': 7.9}
# {'_id': ['Jerry Jameson', 'Pasquale Squitieri'], 'avg_rating': 6.2}
# {'_id': ['Stanislav Govorukhin'], 'avg_rating': 7.5}
# {'_id': ['Martin Shore'], 'avg_rating': 7.8}
# {'_id': ['James Bridges'], 'avg_rating': 6.12}
# {'_id': ['David Gordon Green'], 'avg_rating': 6.55}
# {'_id': ['Owen Harris'], 'avg_rating': 7.2}
# {'_id': ['Young-Sung Sohn'], 'avg_rating': 7.0}
# {'_id': ['Robert Tinnell'], 'avg_rating': 5.0}
# {'_id': ['Don Boyd'], 'avg_rating': 6.1}
# {'_id': ['Stewart Raffill'], 'avg_rating': 5.066666666666666}
# {'_id': ['Chaitanya Tamhane'], 'avg_rating': 7.9}
# {'_id': ['Guillermo Amoedo'], 'avg_rating': 4.9}
# {'_id': ['Massimo Troisi'], 'avg_rating': 7.2}
# {'_id': ['Marcus Ovnell'], 'avg_rating': 7.4}
# {'_id': ['Andrew Ruhemann', 'Shaun Tan'], 'avg_rating': 7.4}
# {'_id': ['Doug Sweetland'], 'avg_rating': 8.5}
# {'_id': ['Maria Sole Tognazzi'], 'avg_rating': 6.3}
# {'_id': ['Del Shores'], 'avg_rating': 7.3}
# {'_id': ['Frank Lin'], 'avg_rating': 5.8}
# {'_id': ['Elaine May'], 'avg_rating': 6.2}
# {'_id': ['Dusan Kovacevic', "Bozidar 'Bota' Nikolic"], 'avg_rating': 8.9}
# {'_id': ['Mike van Diem'], 'avg_rating': 7.466666666666666}
# {'_id': ['Mark Ruffalo'], 'avg_rating': 5.7}
# {'_id': ['Gil Kenan'], 'avg_rating': 6.55}
# {'_id': ['Jonathan Ogilvie'], 'avg_rating': 5.5}
# {'_id': ['Jack Haley Jr.'], 'avg_rating': 7.7}
# {'_id': ['Darren Grodsky', 'Danny Jacobs'], 'avg_rating': 4.7}
# {'_id': ['Marek Kanievska'], 'avg_rating': 7.2}
# {'_id': ['Michael Apted', 'Paul Almond'], 'avg_rating': 8.05}
# {'_id': ['Alain Desrochers'], 'avg_rating': 5.5}
# {'_id': ['Rumle Hammerich'], 'avg_rating': 6.45}
# {'_id': ['Emin Alper'], 'avg_rating': 7.2}
# {'_id': ['S.J. Clarkson'], 'avg_rating': 6.7}
# {'_id': ['Daniel Petrie'], 'avg_rating': 6.716666666666666}
# {'_id': ['Jan Kounen'], 'avg_rating': 6.3}
# {'_id': ['Wilfred Jackson'], 'avg_rating': 7.9}
# {'_id': ['Melvin Frank'], 'avg_rating': 6.68}
# {'_id': ['Brian Caunter'], 'avg_rating': 6.0}
# {'_id': ["Lawrence O'Neil"], 'avg_rating': 5.8}
# {'_id': ['Alex Stapleton'], 'avg_rating': 7.6}
# {'_id': ['Franck Richard'], 'avg_rating': 4.8}
# {'_id': ['Rob Schmidt'], 'avg_rating': 5.766666666666667}
# {'_id': ['Borys Lankosz'], 'avg_rating': 7.1}
# {'_id': ['Andrew Rossi'], 'avg_rating': 6.9}
# {'_id': ['Conrad Rooks'], 'avg_rating': 6.5}
# {'_id': ['Robert Allan Ackerman'], 'avg_rating': 6.5}
# {'_id': ['Joseph Castelo'], 'avg_rating': 7.0}
# {'_id': ['Gerald Potterton'], 'avg_rating': 6.7}
# {'_id': ['Christophe Barratier'], 'avg_rating': 6.833333333333333}
# {'_id': ['Warren P. Sonoda'], 'avg_rating': None}
# {'_id': ['Ellory Elkayem'], 'avg_rating': 5.2}
# {'_id': ['Kristopher Belman'], 'avg_rating': 7.7}
# {'_id': ['Borja Cobeaga'], 'avg_rating': 6.699999999999999}
# {'_id': ['Gregory La Cava'], 'avg_rating': 8.0}
# {'_id': ['Lawrence Shapiro'], 'avg_rating': 7.5}
# {'_id': ['Anthony Powell'], 'avg_rating': 7.6}
# {'_id': ['Jann Turner'], 'avg_rating': 5.6}
# {'_id': ['Karen Oganesyan'], 'avg_rating': 7.3}
# {'_id': ['Akihiko Shiota'], 'avg_rating': 7.075}
# {'_id': ['Nick Matthews'], 'avg_rating': 7.7}
# {'_id': ['Kim Henkel'], 'avg_rating': 3.1}
# {'_id': ['Petra Seeger'], 'avg_rating': 7.3}
# {'_id': ['Peyman Moaadi'], 'avg_rating': 6.9}
# {'_id': ['Rama Burshtein'], 'avg_rating': 6.7}
# {'_id': ['Philippe de Broca'], 'avg_rating': 7.1}
# {'_id': ['Steve Stone'], 'avg_rating': 4.6}
# {'_id': ['Camila Guzmèn Urzèa'], 'avg_rating': 7.3}
# {'_id': ['John Crowley'], 'avg_rating': 7.133333333333333}
# {'_id': ['Krzysztof Lukaszewicz'], 'avg_rating': 6.4}
# {'_id': ['Richard LaGravenese'], 'avg_rating': 6.68}
# {'_id': ['Teresa Fabik'], 'avg_rating': 5.8999999999999995}
# {'_id': ['Rupert Edwards'], 'avg_rating': 7.5}
# {'_id': ['Phil Grabsky'], 'avg_rating': 7.2}
# {'_id': ['Leslie Small'], 'avg_rating': 4.8}
# {'_id': ['Stanley Nelson'], 'avg_rating': 7.466666666666666}
# {'_id': ['Alex Holdridge'], 'avg_rating': 7.3}
# {'_id': ['Tony Collingwood'], 'avg_rating': 6.8}
# {'_id': ['Thomas Gilou'], 'avg_rating': 6.3}
# {'_id': ['John Eng', 'Norton Virgien'], 'avg_rating': 5.5}
# {'_id': ['Tony Gilroy'], 'avg_rating': 6.733333333333333}
# {'_id': ['Michael Chang'], 'avg_rating': 7.1}
# {'_id': ['Sean Gullette'], 'avg_rating': 6.3}
# {'_id': ['Arthur de Pins'], 'avg_rating': 6.8}
# {'_id': ['Thomas Schlamme'], 'avg_rating': 6.0}

# %%
# 컬렉션에 있는 영화의 개수를 계산하세요.
db.movies.count_documents({})
# Out:
# 23539

# %%
# 평균 영화 길이를 찾으세요.
pipeline = [
    {"$group": {"_id": None, "avgTime": {"$avg": "$runtime"}}},
    {"$limit": 3}
]
# for movie in movies.aggregate(pipeline) :
#     print (movie)

result = list(movies.aggregate(pipeline))
result[0]["avgTime"]
# Out:
# 103.78932097696172

# %%
# 각 장르에 대한 영화 개수를 계산하세요!
# 장르를 기준으로 개수를 출력
pipeline = [
    {"$unwind":"$genres"},
    {"$group": {"_id": "$genres", "movieCount": {"$sum":1}}},
    {"$sort" : {"_id": 1}}
]

# for movie in movies.aggregate(pipeline) :
#     print(movie)

genre_count = movies.aggregate(pipeline)
for genre in genre_count :
    print(f"장르 : {genre["_id"]}, 영화 수 : {genre["movieCount"]}")
# Out:
# 장르 : Action, 영화 수 : 2539
# 장르 : Adventure, 영화 수 : 2045
# 장르 : Animation, 영화 수 : 971
# 장르 : Biography, 영화 수 : 1404
# 장르 : Comedy, 영화 수 : 7024
# 장르 : Crime, 영화 수 : 2678
# 장르 : Documentary, 영화 수 : 2129
# 장르 : Drama, 영화 수 : 13789
# 장르 : Family, 영화 수 : 1311
# 장르 : Fantasy, 영화 수 : 1153
# 장르 : Film-Noir, 영화 수 : 105
# 장르 : History, 영화 수 : 999
# 장르 : Horror, 영화 수 : 1703
# 장르 : Music, 영화 수 : 840
# 장르 : Musical, 영화 수 : 487
# 장르 : Mystery, 영화 수 : 1259
# 장르 : News, 영화 수 : 51
# 장르 : Romance, 영화 수 : 3665
# 장르 : Sci-Fi, 영화 수 : 1034
# 장르 : Short, 영화 수 : 478
# 장르 : Sport, 영화 수 : 390
# 장르 : Talk-Show, 영화 수 : 1
# 장르 : Thriller, 영화 수 : 2658
# 장르 : War, 영화 수 : 794
# 장르 : Western, 영화 수 : 274

# %%
# 2015년 이후에 개봉한 영화를 제목순으로 정렬하여 나열해주세요.
pipeline = [
    {"$match": {"year": {"$gte": 2015}}},
    {"$project": {"_id": 0, "title": 1, "year": 1}},
    {"$sort": {"title": 1}},
    {"$limit": 5}
]

for movie in movies.aggregate(pipeline) :
    print(movie)
# Out:
# {'title': '(T)ERROR', 'year': 2015}
# {'title': '11 Minutes', 'year': 2015}
# {'title': '13 Minutes', 'year': 2015}
# {'title': '3 1/2 Minutes, Ten Bullets', 'year': 2015}
# {'title': '45 Years', 'year': 2015}

# %%
# 2015년 이후에 개봉한 영화를 제목순으로 정렬하여 나열해주세요.
for movie in movies.find({"year":{"$gt": 2015}}).sort("title") :
    print(f"영화제목: {movie["title"]}")
# Out:
# 영화제목: The Masked Saint

# %%
#가장 많은 영화를 제작하는 상위 5개 국가를 찾아주세요.
pipeline=[
    {"$unwind": "$countries"},
    {"$group": {"_id":"$countries", "count":{"$sum":1}}},
    {"$sort": {"count":-1}},
    {"$limit": 5}
]

for movie in movies.aggregate(pipeline) :
    print(movie)
# Out:
# {'_id': 'USA', 'count': 11855}
# {'_id': 'France', 'count': 3093}
# {'_id': 'UK', 'count': 2904}
# {'_id': 'Germany', 'count': 1659}
# {'_id': 'Italy', 'count': 1388}

# %%
# 2000년 이후 영화의 연도별 평균 IMDB 평점을 찾으세요.
pipeline = [
    {"$match": {"year": {"$gte": 2000}}},
    {"$group": {"_id": "$year", "avgRating": {"$avg": "$imdb.rating"}}}
]

for movie in movies.aggregate(pipeline) :
    print(movie)
# Out:
# {'_id': 2014, 'avgRating': 6.5637478108581435}
# {'_id': 2002, 'avgRating': 6.561679389312976}
# {'_id': 2003, 'avgRating': 6.577929984779299}
# {'_id': 2013, 'avgRating': 6.48876127973749}
# {'_id': 2015, 'avgRating': 6.94197247706422}
# {'_id': 2005, 'avgRating': 6.591292875989446}
# {'_id': 2000, 'avgRating': 6.539805825242718}
# {'_id': 2016, 'avgRating': None}
# {'_id': 2004, 'avgRating': 6.648852901484481}
# {'_id': 2012, 'avgRating': 6.478068592057761}
# {'_id': 2011, 'avgRating': 6.491538461538461}
# {'_id': 2010, 'avgRating': 6.5279669762641905}
# {'_id': 2001, 'avgRating': 6.584031007751937}
# {'_id': 2006, 'avgRating': 6.618364928909952}
# {'_id': 2009, 'avgRating': 6.517979797979798}
# {'_id': 2008, 'avgRating': 6.573243801652892}
# {'_id': 2007, 'avgRating': 6.607224770642202}

# %%
db.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 db.close()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pymongo\synchronous\collection.py:422, in Collection.__call__(self, *args, **kwargs)
#     420 """This is only here so that some API misusages are easier to debug."""
#     421 if "." not in self._name:
# --> 422     raise TypeError(
#     423         f"'{type(self).__name__}' object is not callable. If you "
#     424         "meant to call the '%s' method on a 'Database' "
#     425         "object it is failing because no such method "
#     426         "exists." % self._name
#     427     )
#     428 raise TypeError(
#     429     f"'{type(self).__name__}' object is not callable. If you meant to "
#     430     f"call the '%s' method on a '{type(self).__name__}' object it is "
#     431     "failing because no such method exists." % self._name.split(".")[-1]
#     432 )
#
# TypeError: 'Collection' object is not callable. If you meant to call the 'close' method on a 'Database' object it is failing because no such method exists.
