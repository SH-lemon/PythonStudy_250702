# %%
import pickle
import pandas as pd

with open("titanic_step2_feature_change.pickle", "rb") as pickle_filename :
    df = pd.read_pickle(pickle_filename)

# %%
# 인코팅 => 특정 사이트 데이터 크롤링 => 주피터 노트북
# 사람이 이해할 수 있는 문법 => 컴퓨터가 이해할 수 있는 형태 : 인코딩
# 컴퓨터가 처리한 문법 => 사람이 이해할 수 있는 형태 : 디코딩

# sklearn & numpy & pandas & plotly
# 레이블 인코딩 => LableEncoding

# 레이블 인코딩 : 문자열 형태의 데이터를 가지고 있다 => 숫자형태의 범주형 카테고리로 분류해서 인코딩
# 원핫 인코딩 => OneHotEncoding : 각 문자열 범주마다 새로운 feature를 만들고 해당 범주에 속하는 경우에만 1값을 부여하는 방식의 인코딩
# BigQuery => even params => key

# %%
df_label = df.copy()
df_onehot = df.copy()

ntrain = 886
train = df[:ntrain]

y_train = train["Survived"].copy()

# %%
drop_features = ["PassengerId", "Survived"]
df_onehot = df_onehot.drop(drop_features, axis = 1).copy()
df_onehot.head()
# Out:
#    Pclass  Sex  Age  Fare  Cabin  Embarked  Initial  Family  Ticket_Initial2  \
# 0       3    0  3.0   0.0      0         0      0.0       2                0
# 1       1    1  4.0   3.0      1         1      2.0       2                1
# 2       3    1  3.0   0.0      0         0      1.0       1                2
# 3       1    1  4.0   2.0      1         0      2.0       2                3
# 4       3    0  4.0   0.0      0         0      0.0       1                3
#
#    Ticket_Num_Cut  HighChance  LowChance
# 0               3           0          0
# 1               3           2          0
# 2               9           0          0
# 3               5           2          0
# 4               9           0          2

# %%
drop_features = ["PassengerId", "Survived"]
df_label = df_label.drop(drop_features, axis = 1).copy()
df_label.head()
# Out:
#    Pclass  Sex  Age  Fare  Cabin  Embarked  Initial  Family  Ticket_Initial2  \
# 0       3    0  3.0   0.0      0         0      0.0       2                0
# 1       1    1  4.0   3.0      1         1      2.0       2                1
# 2       3    1  3.0   0.0      0         0      1.0       1                2
# 3       1    1  4.0   2.0      1         0      2.0       2                3
# 4       3    0  4.0   0.0      0         0      0.0       1                3
#
#    Ticket_Num_Cut  HighChance  LowChance
# 0               3           0          0
# 1               3           2          0
# 2               9           0          0
# 3               5           2          0
# 4               9           0          2

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
df_label = df_label.apply(LabelEncoder().fit_transform)

# %%
df_label.head()
# Out:
#    Pclass  Sex  Age  Fare  Cabin  Embarked  Initial  Family  Ticket_Initial2  \
# 0       2    0    3     0      0         0        0       1                0
# 1       0    1    4     3      1         1        2       1                1
# 2       2    1    3     0      0         0        1       0                2
# 3       0    1    4     2      1         0        2       1                3
# 4       2    0    4     0      0         0        0       0                3
#
#    Ticket_Num_Cut  HighChance  LowChance
# 0               3           0          0
# 1               3           2          0
# 2               9           0          0
# 3               5           2          0
# 4               9           0          2

# %%
onehot_cols = df_label.columns.tolist()
onehot_cols
# Out:
# ['Pclass',
#  'Sex',
#  'Age',
#  'Fare',
#  'Cabin',
#  'Embarked',
#  'Initial',
#  'Family',
#  'Ticket_Initial2',
#  'Ticket_Num_Cut',
#  'HighChance',
#  'LowChance']

# %%
df_oneshot = pd.get_dummies(df_label, columns=onehot_cols)

df_oneshot.head()
# Out:
#    Pclass_0  Pclass_1  Pclass_2  Sex_0  Sex_1  Age_0  Age_1  Age_2  Age_3  \
# 0     False     False      True   True  False  False  False  False   True
# 1      True     False     False  False   True  False  False  False  False
# 2     False     False      True  False   True  False  False  False   True
# 3      True     False     False  False   True  False  False  False  False
# 4     False     False      True   True  False  False  False  False  False
#
#    Age_4  ...  HighChance_0  HighChance_1  HighChance_2  HighChance_3  \
# 0  False  ...          True         False         False         False
# 1   True  ...         False         False          True         False
# 2  False  ...          True         False         False         False
# 3   True  ...         False         False          True         False
# 4   True  ...          True         False         False         False
#
#    HighChance_4  HighChance_5  HighChance_6  LowChance_0  LowChance_1  \
# 0         False         False         False         True        False
# 1         False         False         False         True        False
# 2         False         False         False         True        False
# 3         False         False         False         True        False
# 4         False         False         False        False        False
#
#    LowChance_2
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#
# [5 rows x 92 columns]

# %%
import pickle

with open("titanic_step3_feature_encoding.pickle") as pickle_filename :
    pickle.dump(df_onehot, pickle_filename)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 import pickle
# ----> 3 with open("titanic_step3_feature_encoding.pickle") as pickle_filename :
#       4     pickle.dump(df_onehot, pickle_filename)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'titanic_step3_feature_encoding.pickle'
