# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options = options)

driver.get("https://www.instagram.com/accounts/login/")
print("수동으로 인증 시작!")
time.sleep(30)

with open("instagram_cookies.pkl", "wb") as f :
    pickle.dump(driver.get_cookies(), f)

print("쿠키 저장 완료")
driver.quit()
# Out:
# 수동으로 인증 시작!
# 쿠키 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options = options)

driver.get("https://www.instagram.com")

with open("instagram_cookies.pkl", "rb") as f :
    cookies = pickle.load(f)
for cookie in cookies :
    driver.add_cookie(cookie)

driver.refresh()
time.sleep(5)

try:
    not_now = driver.find_element(By.XPATH, "//button[text()='나중에 하기']")
    not_now.click()
    time.sleep(2)
except:
    pass

keyword = "여름패션"
driver.get(f"https://www.instagram.com/explore/tags/{keyword}")
time.sleep(5)

post_links = set()
for _ in range(3) :
    links = driver.find_elements(By.TAG_NAME, "a")
    for link in links :
        href = link.get_attribute("href")
        if href and "/p/" in href :
            post_links.add(href)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(3)

results = []
for url in list(post_links)[:10] :
    driver.get(url)
    time.sleep(3)
    caption = ""

    try :
        img_tag = driver.find_element(By.XPATH, "//img[@alt]")
        caption = img_tag.get_attribute("alt").strip()
        results.append({"url": url, "caption": caption})
    except Exception as e :
        print(f"캡션 추출 실패 : {url} | 에러 : {e}")
        continue

driver.quit()

for r in results :
    print(r["url"])
    print(r["caption"])
    print("="*60)
# Out:
# https://www.instagram.com/p/DKlx7s_JOC7/
# Photo by MAGAZINE OF LOE • 로이 매거진 on June 06, 2025. 사람 1명, 파이 및 문구: 'LOE'S CLOSET 추구미= 추구미=에겐녀 = 에겐녀 단돈 5만원으로 완벽 에겐녀 되는 에겐녀되는방법 방법'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLCnUhaPnld/
# Photo by w.Art magazine 더아트매거진 on June 18, 2025. 사람 1명, 잡지, 상의 및 문구: 'CultureFashion Culture Fashion 대충 걸쳐도 예쁘잖아요 나만 알고싶어.. ပူပဇပ いとん 이런 감성이 좋아 최애 아이템 추천 추천.zip zip w.Art Magazine'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMcujJ0BnL1/
# Photo shared by IGOTSHE magazine 아가씨 매거진 on July 23, 2025 tagging @hane_seoul. 사람 1명 및 문구: 'IGOTSHE MAGAZINE 넌왜 넌 넌왜휴가가잔 가잔 말을 옷 없을 때 하니 바캉스 item 단독가 보장! 지고재그 with 하네'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DK86lzjxMtU/
# Photo by 오뭐입? on June 15, 2025. 사람 3명 및 문구: 'onl 주말에 입고 싶은 여름 데일리 코디 모음'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/C9r93cdPXqy/
# #닝닝 #에스파 #ningning #aespa #ningningaespa #닝닝패션 #닝닝코디 #여친룩코디 #여름패션 #여름코디 에스파닝닝 여친짤 여친룩 여름룩 민소매 슬리브리스 나시 탑 여름 봄 치마
# ============================================================
# https://www.instagram.com/p/DJ8iuA3pdlZ/
# Photo by 오뭐입? on May 21, 2025. 상의 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLtdF-kBWkR/
# Photo by 셀패진 on July 04, 2025. 사람 1명 및 문구: '노정농용연 Celeb Fashion Magazine 여자 연예인 애착 팔찌 얼마?'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DL4py8YzNPN/
# Photo shared by 블랭크 BL magazine on July 09, 2025 tagging @jennierubyjane. 사람 1명 및 문구: 'ANK BLL Nennie ennie 찐여름 찐 여름 코디 공식 하나만 해도 당신은 헛쟁이'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DJnVSKVSvq4/
# Photo by 그리니 on May 13, 2025. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DL4uu0ySvHb/
# Photo by sonminsu on July 09, 2025. 사람 1명 및 문구: 'emis 레드템 없이 여름 못 산다 산다전언 선언 여름철 레드템운 선택이 아닌 필수가되 되 SONMINSU NMINSI'의 이미지일 수 있음.
# ============================================================
